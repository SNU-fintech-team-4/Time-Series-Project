# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller, kpss
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df = pd.read_csv("./ori/preprocessed_quarterly_data.csv")
df
# Out:
#       series_id     date       value
# 0            T1  1979-01   3592.5500
# 1            T1  1979-05   6409.3403
# 2            T1  1979-09  10953.4928
# 3            T1  1980-01   4136.8453
# 4            T1  1980-05   3369.4600
# ...         ...      ...         ...
# 42539      T427  2006-01   8915.0000
# 42540      T427  2006-05   7435.0000
# 42541      T427  2006-09  18986.0000
# 42542      T427  2007-01  24239.0000
# 42543      T427  2007-05   7865.0000
#
# [42544 rows x 3 columns]

# %%
# 저장할 폴더 경로
output_folder = "data_qua"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# DataFrame df를 "series_id" 컬럼 기준으로 그룹화 후 각 그룹을 CSV 파일로 저장
for series_id, group in df.groupby('series_id'):
    file_name = f"{series_id}.csv"  # 예: T1.csv, T2.csv, ...
    file_path = os.path.join(output_folder, file_name)
    group.to_csv(file_path, index=False)
    print(f"{series_id} 그룹이 {file_path}에 저장되었습니다.")
# Out:
# T1 그룹이 data_qua\T1.csv에 저장되었습니다.
# T10 그룹이 data_qua\T10.csv에 저장되었습니다.
# T100 그룹이 data_qua\T100.csv에 저장되었습니다.
# T101 그룹이 data_qua\T101.csv에 저장되었습니다.
# T102 그룹이 data_qua\T102.csv에 저장되었습니다.
# T103 그룹이 data_qua\T103.csv에 저장되었습니다.
# T104 그룹이 data_qua\T104.csv에 저장되었습니다.
# T105 그룹이 data_qua\T105.csv에 저장되었습니다.
# T106 그룹이 data_qua\T106.csv에 저장되었습니다.
# T107 그룹이 data_qua\T107.csv에 저장되었습니다.
# T108 그룹이 data_qua\T108.csv에 저장되었습니다.
# T109 그룹이 data_qua\T109.csv에 저장되었습니다.
# T11 그룹이 data_qua\T11.csv에 저장되었습니다.
# T110 그룹이 data_qua\T110.csv에 저장되었습니다.
# T111 그룹이 data_qua\T111.csv에 저장되었습니다.
# T112 그룹이 data_qua\T112.csv에 저장되었습니다.
# T113 그룹이 data_qua\T113.csv에 저장되었습니다.
# T114 그룹이 data_qua\T114.csv에 저장되었습니다.
# T115 그룹이 data_qua\T115.csv에 저장되었습니다.
# T116 그룹이 data_qua\T116.csv에 저장되었습니다.
# T117 그룹이 data_qua\T117.csv에 저장되었습니다.
# T118 그룹이 data_qua\T118.csv에 저장되었습니다.
# T119 그룹이 data_qua\T119.csv에 저장되었습니다.
# T12 그룹이 data_qua\T12.csv에 저장되었습니다.
# T120 그룹이 data_qua\T120.csv에 저장되었습니다.
# T121 그룹이 data_qua\T121.csv에 저장되었습니다.
# T122 그룹이 data_qua\T122.csv에 저장되었습니다.
# T123 그룹이 data_qua\T123.csv에 저장되었습니다.
# T124 그룹이 data_qua\T124.csv에 저장되었습니다.
# T125 그룹이 data_qua\T125.csv에 저장되었습니다.
# T126 그룹이 data_qua\T126.csv에 저장되었습니다.
# T127 그룹이 data_qua\T127.csv에 저장되었습니다.
# T128 그룹이 data_qua\T128.csv에 저장되었습니다.
# T129 그룹이 data_qua\T129.csv에 저장되었습니다.
# T13 그룹이 data_qua\T13.csv에 저장되었습니다.
# T130 그룹이 data_qua\T130.csv에 저장되었습니다.
# T131 그룹이 data_qua\T131.csv에 저장되었습니다.
# T132 그룹이 data_qua\T132.csv에 저장되었습니다.
# T133 그룹이 data_qua\T133.csv에 저장되었습니다.
# T134 그룹이 data_qua\T134.csv에 저장되었습니다.
# T135 그룹이 data_qua\T135.csv에 저장되었습니다.
# T136 그룹이 data_qua\T136.csv에 저장되었습니다.
# T137 그룹이 data_qua\T137.csv에 저장되었습니다.
# T138 그룹이 data_qua\T138.csv에 저장되었습니다.
# T139 그룹이 data_qua\T139.csv에 저장되었습니다.
# T14 그룹이 data_qua\T14.csv에 저장되었습니다.
# T140 그룹이 data_qua\T140.csv에 저장되었습니다.
# T141 그룹이 data_qua\T141.csv에 저장되었습니다.
# T142 그룹이 data_qua\T142.csv에 저장되었습니다.
# T143 그룹이 data_qua\T143.csv에 저장되었습니다.
# T144 그룹이 data_qua\T144.csv에 저장되었습니다.
# T145 그룹이 data_qua\T145.csv에 저장되었습니다.
# T146 그룹이 data_qua\T146.csv에 저장되었습니다.
# T147 그룹이 data_qua\T147.csv에 저장되었습니다.
# T148 그룹이 data_qua\T148.csv에 저장되었습니다.
# T149 그룹이 data_qua\T149.csv에 저장되었습니다.
# T15 그룹이 data_qua\T15.csv에 저장되었습니다.
# T150 그룹이 data_qua\T150.csv에 저장되었습니다.
# T151 그룹이 data_qua\T151.csv에 저장되었습니다.
# T152 그룹이 data_qua\T152.csv에 저장되었습니다.
# T153 그룹이 data_qua\T153.csv에 저장되었습니다.
# T154 그룹이 data_qua\T154.csv에 저장되었습니다.
# T155 그룹이 data_qua\T155.csv에 저장되었습니다.
# T156 그룹이 data_qua\T156.csv에 저장되었습니다.
# T157 그룹이 data_qua\T157.csv에 저장되었습니다.
# T158 그룹이 data_qua\T158.csv에 저장되었습니다.
# T159 그룹이 data_qua\T159.csv에 저장되었습니다.
# T16 그룹이 data_qua\T16.csv에 저장되었습니다.
# T160 그룹이 data_qua\T160.csv에 저장되었습니다.
# T161 그룹이 data_qua\T161.csv에 저장되었습니다.
# T162 그룹이 data_qua\T162.csv에 저장되었습니다.
# T163 그룹이 data_qua\T163.csv에 저장되었습니다.
# T164 그룹이 data_qua\T164.csv에 저장되었습니다.
# T165 그룹이 data_qua\T165.csv에 저장되었습니다.
# T166 그룹이 data_qua\T166.csv에 저장되었습니다.
# T167 그룹이 data_qua\T167.csv에 저장되었습니다.
# T168 그룹이 data_qua\T168.csv에 저장되었습니다.
# T169 그룹이 data_qua\T169.csv에 저장되었습니다.
# T17 그룹이 data_qua\T17.csv에 저장되었습니다.
# T170 그룹이 data_qua\T170.csv에 저장되었습니다.
# T171 그룹이 data_qua\T171.csv에 저장되었습니다.
# T172 그룹이 data_qua\T172.csv에 저장되었습니다.
# T173 그룹이 data_qua\T173.csv에 저장되었습니다.
# T174 그룹이 data_qua\T174.csv에 저장되었습니다.
# T175 그룹이 data_qua\T175.csv에 저장되었습니다.
# T176 그룹이 data_qua\T176.csv에 저장되었습니다.
# T177 그룹이 data_qua\T177.csv에 저장되었습니다.
# T178 그룹이 data_qua\T178.csv에 저장되었습니다.
# T179 그룹이 data_qua\T179.csv에 저장되었습니다.
# T18 그룹이 data_qua\T18.csv에 저장되었습니다.
# T180 그룹이 data_qua\T180.csv에 저장되었습니다.
# T181 그룹이 data_qua\T181.csv에 저장되었습니다.
# T182 그룹이 data_qua\T182.csv에 저장되었습니다.
# T183 그룹이 data_qua\T183.csv에 저장되었습니다.
# T184 그룹이 data_qua\T184.csv에 저장되었습니다.
# T185 그룹이 data_qua\T185.csv에 저장되었습니다.
# T186 그룹이 data_qua\T186.csv에 저장되었습니다.
# T187 그룹이 data_qua\T187.csv에 저장되었습니다.
# T188 그룹이 data_qua\T188.csv에 저장되었습니다.
# T189 그룹이 data_qua\T189.csv에 저장되었습니다.
# T19 그룹이 data_qua\T19.csv에 저장되었습니다.
# T190 그룹이 data_qua\T190.csv에 저장되었습니다.
# T191 그룹이 data_qua\T191.csv에 저장되었습니다.
# T192 그룹이 data_qua\T192.csv에 저장되었습니다.
# T193 그룹이 data_qua\T193.csv에 저장되었습니다.
# T194 그룹이 data_qua\T194.csv에 저장되었습니다.
# T195 그룹이 data_qua\T195.csv에 저장되었습니다.
# T196 그룹이 data_qua\T196.csv에 저장되었습니다.
# T197 그룹이 data_qua\T197.csv에 저장되었습니다.
# T198 그룹이 data_qua\T198.csv에 저장되었습니다.
# T199 그룹이 data_qua\T199.csv에 저장되었습니다.
# T2 그룹이 data_qua\T2.csv에 저장되었습니다.
# T20 그룹이 data_qua\T20.csv에 저장되었습니다.
# T200 그룹이 data_qua\T200.csv에 저장되었습니다.
# T201 그룹이 data_qua\T201.csv에 저장되었습니다.
# T202 그룹이 data_qua\T202.csv에 저장되었습니다.
# T203 그룹이 data_qua\T203.csv에 저장되었습니다.
# T204 그룹이 data_qua\T204.csv에 저장되었습니다.
# T205 그룹이 data_qua\T205.csv에 저장되었습니다.
# T206 그룹이 data_qua\T206.csv에 저장되었습니다.
# T207 그룹이 data_qua\T207.csv에 저장되었습니다.
# T208 그룹이 data_qua\T208.csv에 저장되었습니다.
# T209 그룹이 data_qua\T209.csv에 저장되었습니다.
# T21 그룹이 data_qua\T21.csv에 저장되었습니다.
# T210 그룹이 data_qua\T210.csv에 저장되었습니다.
# T211 그룹이 data_qua\T211.csv에 저장되었습니다.
# T212 그룹이 data_qua\T212.csv에 저장되었습니다.
# T213 그룹이 data_qua\T213.csv에 저장되었습니다.
# T214 그룹이 data_qua\T214.csv에 저장되었습니다.
# T215 그룹이 data_qua\T215.csv에 저장되었습니다.
# T216 그룹이 data_qua\T216.csv에 저장되었습니다.
# T217 그룹이 data_qua\T217.csv에 저장되었습니다.
# T218 그룹이 data_qua\T218.csv에 저장되었습니다.
# T219 그룹이 data_qua\T219.csv에 저장되었습니다.
# T22 그룹이 data_qua\T22.csv에 저장되었습니다.
# T220 그룹이 data_qua\T220.csv에 저장되었습니다.
# T221 그룹이 data_qua\T221.csv에 저장되었습니다.
# T222 그룹이 data_qua\T222.csv에 저장되었습니다.
# T223 그룹이 data_qua\T223.csv에 저장되었습니다.
# T224 그룹이 data_qua\T224.csv에 저장되었습니다.
# T225 그룹이 data_qua\T225.csv에 저장되었습니다.
# T226 그룹이 data_qua\T226.csv에 저장되었습니다.
# T227 그룹이 data_qua\T227.csv에 저장되었습니다.
# T228 그룹이 data_qua\T228.csv에 저장되었습니다.
# T229 그룹이 data_qua\T229.csv에 저장되었습니다.
# T23 그룹이 data_qua\T23.csv에 저장되었습니다.
# T230 그룹이 data_qua\T230.csv에 저장되었습니다.
# T231 그룹이 data_qua\T231.csv에 저장되었습니다.
# T232 그룹이 data_qua\T232.csv에 저장되었습니다.
# T233 그룹이 data_qua\T233.csv에 저장되었습니다.
# T234 그룹이 data_qua\T234.csv에 저장되었습니다.
# T235 그룹이 data_qua\T235.csv에 저장되었습니다.
# T236 그룹이 data_qua\T236.csv에 저장되었습니다.
# T237 그룹이 data_qua\T237.csv에 저장되었습니다.
# T238 그룹이 data_qua\T238.csv에 저장되었습니다.
# T239 그룹이 data_qua\T239.csv에 저장되었습니다.
# T24 그룹이 data_qua\T24.csv에 저장되었습니다.
# T240 그룹이 data_qua\T240.csv에 저장되었습니다.
# T241 그룹이 data_qua\T241.csv에 저장되었습니다.
# T242 그룹이 data_qua\T242.csv에 저장되었습니다.
# T243 그룹이 data_qua\T243.csv에 저장되었습니다.
# T244 그룹이 data_qua\T244.csv에 저장되었습니다.
# T245 그룹이 data_qua\T245.csv에 저장되었습니다.
# T246 그룹이 data_qua\T246.csv에 저장되었습니다.
# T247 그룹이 data_qua\T247.csv에 저장되었습니다.
# T248 그룹이 data_qua\T248.csv에 저장되었습니다.
# T249 그룹이 data_qua\T249.csv에 저장되었습니다.
# T25 그룹이 data_qua\T25.csv에 저장되었습니다.
# T250 그룹이 data_qua\T250.csv에 저장되었습니다.
# T251 그룹이 data_qua\T251.csv에 저장되었습니다.
# T252 그룹이 data_qua\T252.csv에 저장되었습니다.
# T253 그룹이 data_qua\T253.csv에 저장되었습니다.
# T254 그룹이 data_qua\T254.csv에 저장되었습니다.
# T255 그룹이 data_qua\T255.csv에 저장되었습니다.
# T256 그룹이 data_qua\T256.csv에 저장되었습니다.
# T257 그룹이 data_qua\T257.csv에 저장되었습니다.
# T258 그룹이 data_qua\T258.csv에 저장되었습니다.
# T259 그룹이 data_qua\T259.csv에 저장되었습니다.
# T26 그룹이 data_qua\T26.csv에 저장되었습니다.
# T260 그룹이 data_qua\T260.csv에 저장되었습니다.
# T261 그룹이 data_qua\T261.csv에 저장되었습니다.
# T262 그룹이 data_qua\T262.csv에 저장되었습니다.
# T263 그룹이 data_qua\T263.csv에 저장되었습니다.
# T264 그룹이 data_qua\T264.csv에 저장되었습니다.
# T265 그룹이 data_qua\T265.csv에 저장되었습니다.
# T266 그룹이 data_qua\T266.csv에 저장되었습니다.
# T267 그룹이 data_qua\T267.csv에 저장되었습니다.
# T268 그룹이 data_qua\T268.csv에 저장되었습니다.
# T269 그룹이 data_qua\T269.csv에 저장되었습니다.
# T27 그룹이 data_qua\T27.csv에 저장되었습니다.
# T270 그룹이 data_qua\T270.csv에 저장되었습니다.
# T271 그룹이 data_qua\T271.csv에 저장되었습니다.
# T272 그룹이 data_qua\T272.csv에 저장되었습니다.
# T273 그룹이 data_qua\T273.csv에 저장되었습니다.
# T274 그룹이 data_qua\T274.csv에 저장되었습니다.
# T275 그룹이 data_qua\T275.csv에 저장되었습니다.
# T276 그룹이 data_qua\T276.csv에 저장되었습니다.
# T277 그룹이 data_qua\T277.csv에 저장되었습니다.
# T278 그룹이 data_qua\T278.csv에 저장되었습니다.
# T279 그룹이 data_qua\T279.csv에 저장되었습니다.
# T28 그룹이 data_qua\T28.csv에 저장되었습니다.
# T280 그룹이 data_qua\T280.csv에 저장되었습니다.
# T281 그룹이 data_qua\T281.csv에 저장되었습니다.
# T282 그룹이 data_qua\T282.csv에 저장되었습니다.
# T283 그룹이 data_qua\T283.csv에 저장되었습니다.
# T284 그룹이 data_qua\T284.csv에 저장되었습니다.
# T285 그룹이 data_qua\T285.csv에 저장되었습니다.
# T286 그룹이 data_qua\T286.csv에 저장되었습니다.
# T287 그룹이 data_qua\T287.csv에 저장되었습니다.
# T288 그룹이 data_qua\T288.csv에 저장되었습니다.
# T289 그룹이 data_qua\T289.csv에 저장되었습니다.
# T29 그룹이 data_qua\T29.csv에 저장되었습니다.
# T290 그룹이 data_qua\T290.csv에 저장되었습니다.
# T291 그룹이 data_qua\T291.csv에 저장되었습니다.
# T292 그룹이 data_qua\T292.csv에 저장되었습니다.
# T293 그룹이 data_qua\T293.csv에 저장되었습니다.
# T294 그룹이 data_qua\T294.csv에 저장되었습니다.
# T295 그룹이 data_qua\T295.csv에 저장되었습니다.
# T296 그룹이 data_qua\T296.csv에 저장되었습니다.
# T297 그룹이 data_qua\T297.csv에 저장되었습니다.
# T298 그룹이 data_qua\T298.csv에 저장되었습니다.
# T299 그룹이 data_qua\T299.csv에 저장되었습니다.
# T3 그룹이 data_qua\T3.csv에 저장되었습니다.
# T30 그룹이 data_qua\T30.csv에 저장되었습니다.
# T300 그룹이 data_qua\T300.csv에 저장되었습니다.
# T301 그룹이 data_qua\T301.csv에 저장되었습니다.
# T302 그룹이 data_qua\T302.csv에 저장되었습니다.
# T303 그룹이 data_qua\T303.csv에 저장되었습니다.
# T304 그룹이 data_qua\T304.csv에 저장되었습니다.
# T305 그룹이 data_qua\T305.csv에 저장되었습니다.
# T306 그룹이 data_qua\T306.csv에 저장되었습니다.
# T307 그룹이 data_qua\T307.csv에 저장되었습니다.
# T308 그룹이 data_qua\T308.csv에 저장되었습니다.
# T309 그룹이 data_qua\T309.csv에 저장되었습니다.
# T31 그룹이 data_qua\T31.csv에 저장되었습니다.
# T310 그룹이 data_qua\T310.csv에 저장되었습니다.
# T311 그룹이 data_qua\T311.csv에 저장되었습니다.
# T312 그룹이 data_qua\T312.csv에 저장되었습니다.
# T313 그룹이 data_qua\T313.csv에 저장되었습니다.
# T314 그룹이 data_qua\T314.csv에 저장되었습니다.
# T315 그룹이 data_qua\T315.csv에 저장되었습니다.
# T316 그룹이 data_qua\T316.csv에 저장되었습니다.
# T317 그룹이 data_qua\T317.csv에 저장되었습니다.
# T318 그룹이 data_qua\T318.csv에 저장되었습니다.
# T319 그룹이 data_qua\T319.csv에 저장되었습니다.
# T32 그룹이 data_qua\T32.csv에 저장되었습니다.
# T320 그룹이 data_qua\T320.csv에 저장되었습니다.
# T321 그룹이 data_qua\T321.csv에 저장되었습니다.
# T322 그룹이 data_qua\T322.csv에 저장되었습니다.
# T323 그룹이 data_qua\T323.csv에 저장되었습니다.
# T324 그룹이 data_qua\T324.csv에 저장되었습니다.
# T325 그룹이 data_qua\T325.csv에 저장되었습니다.
# T326 그룹이 data_qua\T326.csv에 저장되었습니다.
# T327 그룹이 data_qua\T327.csv에 저장되었습니다.
# T328 그룹이 data_qua\T328.csv에 저장되었습니다.
# T329 그룹이 data_qua\T329.csv에 저장되었습니다.
# T33 그룹이 data_qua\T33.csv에 저장되었습니다.
# T330 그룹이 data_qua\T330.csv에 저장되었습니다.
# T331 그룹이 data_qua\T331.csv에 저장되었습니다.
# T332 그룹이 data_qua\T332.csv에 저장되었습니다.
# T333 그룹이 data_qua\T333.csv에 저장되었습니다.
# T334 그룹이 data_qua\T334.csv에 저장되었습니다.
# T335 그룹이 data_qua\T335.csv에 저장되었습니다.
# T336 그룹이 data_qua\T336.csv에 저장되었습니다.
# T337 그룹이 data_qua\T337.csv에 저장되었습니다.
# T338 그룹이 data_qua\T338.csv에 저장되었습니다.
# T339 그룹이 data_qua\T339.csv에 저장되었습니다.
# T34 그룹이 data_qua\T34.csv에 저장되었습니다.
# T340 그룹이 data_qua\T340.csv에 저장되었습니다.
# T341 그룹이 data_qua\T341.csv에 저장되었습니다.
# T342 그룹이 data_qua\T342.csv에 저장되었습니다.
# T343 그룹이 data_qua\T343.csv에 저장되었습니다.
# T344 그룹이 data_qua\T344.csv에 저장되었습니다.
# T345 그룹이 data_qua\T345.csv에 저장되었습니다.
# T346 그룹이 data_qua\T346.csv에 저장되었습니다.
# T347 그룹이 data_qua\T347.csv에 저장되었습니다.
# T348 그룹이 data_qua\T348.csv에 저장되었습니다.
# T349 그룹이 data_qua\T349.csv에 저장되었습니다.
# T35 그룹이 data_qua\T35.csv에 저장되었습니다.
# T350 그룹이 data_qua\T350.csv에 저장되었습니다.
# T351 그룹이 data_qua\T351.csv에 저장되었습니다.
# T352 그룹이 data_qua\T352.csv에 저장되었습니다.
# T353 그룹이 data_qua\T353.csv에 저장되었습니다.
# T354 그룹이 data_qua\T354.csv에 저장되었습니다.
# T355 그룹이 data_qua\T355.csv에 저장되었습니다.
# T356 그룹이 data_qua\T356.csv에 저장되었습니다.
# T357 그룹이 data_qua\T357.csv에 저장되었습니다.
# T358 그룹이 data_qua\T358.csv에 저장되었습니다.
# T359 그룹이 data_qua\T359.csv에 저장되었습니다.
# T36 그룹이 data_qua\T36.csv에 저장되었습니다.
# T360 그룹이 data_qua\T360.csv에 저장되었습니다.
# T361 그룹이 data_qua\T361.csv에 저장되었습니다.
# T362 그룹이 data_qua\T362.csv에 저장되었습니다.
# T363 그룹이 data_qua\T363.csv에 저장되었습니다.
# T364 그룹이 data_qua\T364.csv에 저장되었습니다.
# T365 그룹이 data_qua\T365.csv에 저장되었습니다.
# T366 그룹이 data_qua\T366.csv에 저장되었습니다.
# T367 그룹이 data_qua\T367.csv에 저장되었습니다.
# T368 그룹이 data_qua\T368.csv에 저장되었습니다.
# T369 그룹이 data_qua\T369.csv에 저장되었습니다.
# T37 그룹이 data_qua\T37.csv에 저장되었습니다.
# T370 그룹이 data_qua\T370.csv에 저장되었습니다.
# T371 그룹이 data_qua\T371.csv에 저장되었습니다.
# T372 그룹이 data_qua\T372.csv에 저장되었습니다.
# T373 그룹이 data_qua\T373.csv에 저장되었습니다.
# T374 그룹이 data_qua\T374.csv에 저장되었습니다.
# T375 그룹이 data_qua\T375.csv에 저장되었습니다.
# T376 그룹이 data_qua\T376.csv에 저장되었습니다.
# T377 그룹이 data_qua\T377.csv에 저장되었습니다.
# T378 그룹이 data_qua\T378.csv에 저장되었습니다.
# T379 그룹이 data_qua\T379.csv에 저장되었습니다.
# T38 그룹이 data_qua\T38.csv에 저장되었습니다.
# T380 그룹이 data_qua\T380.csv에 저장되었습니다.
# T381 그룹이 data_qua\T381.csv에 저장되었습니다.
# T382 그룹이 data_qua\T382.csv에 저장되었습니다.
# T383 그룹이 data_qua\T383.csv에 저장되었습니다.
# T384 그룹이 data_qua\T384.csv에 저장되었습니다.
# T385 그룹이 data_qua\T385.csv에 저장되었습니다.
# T386 그룹이 data_qua\T386.csv에 저장되었습니다.
# T387 그룹이 data_qua\T387.csv에 저장되었습니다.
# T388 그룹이 data_qua\T388.csv에 저장되었습니다.
# T389 그룹이 data_qua\T389.csv에 저장되었습니다.
# T39 그룹이 data_qua\T39.csv에 저장되었습니다.
# T390 그룹이 data_qua\T390.csv에 저장되었습니다.
# T391 그룹이 data_qua\T391.csv에 저장되었습니다.
# T392 그룹이 data_qua\T392.csv에 저장되었습니다.
# T393 그룹이 data_qua\T393.csv에 저장되었습니다.
# T394 그룹이 data_qua\T394.csv에 저장되었습니다.
# T395 그룹이 data_qua\T395.csv에 저장되었습니다.
# T396 그룹이 data_qua\T396.csv에 저장되었습니다.
# T397 그룹이 data_qua\T397.csv에 저장되었습니다.
# T398 그룹이 data_qua\T398.csv에 저장되었습니다.
# T399 그룹이 data_qua\T399.csv에 저장되었습니다.
# T4 그룹이 data_qua\T4.csv에 저장되었습니다.
# T40 그룹이 data_qua\T40.csv에 저장되었습니다.
# T400 그룹이 data_qua\T400.csv에 저장되었습니다.
# T401 그룹이 data_qua\T401.csv에 저장되었습니다.
# T402 그룹이 data_qua\T402.csv에 저장되었습니다.
# T403 그룹이 data_qua\T403.csv에 저장되었습니다.
# T404 그룹이 data_qua\T404.csv에 저장되었습니다.
# T405 그룹이 data_qua\T405.csv에 저장되었습니다.
# T406 그룹이 data_qua\T406.csv에 저장되었습니다.
# T407 그룹이 data_qua\T407.csv에 저장되었습니다.
# T408 그룹이 data_qua\T408.csv에 저장되었습니다.
# T409 그룹이 data_qua\T409.csv에 저장되었습니다.
# T41 그룹이 data_qua\T41.csv에 저장되었습니다.
# T410 그룹이 data_qua\T410.csv에 저장되었습니다.
# T411 그룹이 data_qua\T411.csv에 저장되었습니다.
# T412 그룹이 data_qua\T412.csv에 저장되었습니다.
# T413 그룹이 data_qua\T413.csv에 저장되었습니다.
# T414 그룹이 data_qua\T414.csv에 저장되었습니다.
# T415 그룹이 data_qua\T415.csv에 저장되었습니다.
# T416 그룹이 data_qua\T416.csv에 저장되었습니다.
# T417 그룹이 data_qua\T417.csv에 저장되었습니다.
# T418 그룹이 data_qua\T418.csv에 저장되었습니다.
# T419 그룹이 data_qua\T419.csv에 저장되었습니다.
# T42 그룹이 data_qua\T42.csv에 저장되었습니다.
# T420 그룹이 data_qua\T420.csv에 저장되었습니다.
# T421 그룹이 data_qua\T421.csv에 저장되었습니다.
# T422 그룹이 data_qua\T422.csv에 저장되었습니다.
# T423 그룹이 data_qua\T423.csv에 저장되었습니다.
# T424 그룹이 data_qua\T424.csv에 저장되었습니다.
# T425 그룹이 data_qua\T425.csv에 저장되었습니다.
# T426 그룹이 data_qua\T426.csv에 저장되었습니다.
# T427 그룹이 data_qua\T427.csv에 저장되었습니다.
# T43 그룹이 data_qua\T43.csv에 저장되었습니다.
# T44 그룹이 data_qua\T44.csv에 저장되었습니다.
# T45 그룹이 data_qua\T45.csv에 저장되었습니다.
# T46 그룹이 data_qua\T46.csv에 저장되었습니다.
# T47 그룹이 data_qua\T47.csv에 저장되었습니다.
# T48 그룹이 data_qua\T48.csv에 저장되었습니다.
# T49 그룹이 data_qua\T49.csv에 저장되었습니다.
# T5 그룹이 data_qua\T5.csv에 저장되었습니다.
# T50 그룹이 data_qua\T50.csv에 저장되었습니다.
# T51 그룹이 data_qua\T51.csv에 저장되었습니다.
# T52 그룹이 data_qua\T52.csv에 저장되었습니다.
# T53 그룹이 data_qua\T53.csv에 저장되었습니다.
# T54 그룹이 data_qua\T54.csv에 저장되었습니다.
# T55 그룹이 data_qua\T55.csv에 저장되었습니다.
# T56 그룹이 data_qua\T56.csv에 저장되었습니다.
# T57 그룹이 data_qua\T57.csv에 저장되었습니다.
# T58 그룹이 data_qua\T58.csv에 저장되었습니다.
# T59 그룹이 data_qua\T59.csv에 저장되었습니다.
# T6 그룹이 data_qua\T6.csv에 저장되었습니다.
# T60 그룹이 data_qua\T60.csv에 저장되었습니다.
# T61 그룹이 data_qua\T61.csv에 저장되었습니다.
# T62 그룹이 data_qua\T62.csv에 저장되었습니다.
# T63 그룹이 data_qua\T63.csv에 저장되었습니다.
# T64 그룹이 data_qua\T64.csv에 저장되었습니다.
# T65 그룹이 data_qua\T65.csv에 저장되었습니다.
# T66 그룹이 data_qua\T66.csv에 저장되었습니다.
# T67 그룹이 data_qua\T67.csv에 저장되었습니다.
# T68 그룹이 data_qua\T68.csv에 저장되었습니다.
# T69 그룹이 data_qua\T69.csv에 저장되었습니다.
# T7 그룹이 data_qua\T7.csv에 저장되었습니다.
# T70 그룹이 data_qua\T70.csv에 저장되었습니다.
# T71 그룹이 data_qua\T71.csv에 저장되었습니다.
# T72 그룹이 data_qua\T72.csv에 저장되었습니다.
# T73 그룹이 data_qua\T73.csv에 저장되었습니다.
# T74 그룹이 data_qua\T74.csv에 저장되었습니다.
# T75 그룹이 data_qua\T75.csv에 저장되었습니다.
# T76 그룹이 data_qua\T76.csv에 저장되었습니다.
# T77 그룹이 data_qua\T77.csv에 저장되었습니다.
# T78 그룹이 data_qua\T78.csv에 저장되었습니다.
# T79 그룹이 data_qua\T79.csv에 저장되었습니다.
# T8 그룹이 data_qua\T8.csv에 저장되었습니다.
# T80 그룹이 data_qua\T80.csv에 저장되었습니다.
# T81 그룹이 data_qua\T81.csv에 저장되었습니다.
# T82 그룹이 data_qua\T82.csv에 저장되었습니다.
# T83 그룹이 data_qua\T83.csv에 저장되었습니다.
# T84 그룹이 data_qua\T84.csv에 저장되었습니다.
# T85 그룹이 data_qua\T85.csv에 저장되었습니다.
# T86 그룹이 data_qua\T86.csv에 저장되었습니다.
# T87 그룹이 data_qua\T87.csv에 저장되었습니다.
# T88 그룹이 data_qua\T88.csv에 저장되었습니다.
# T89 그룹이 data_qua\T89.csv에 저장되었습니다.
# T9 그룹이 data_qua\T9.csv에 저장되었습니다.
# T90 그룹이 data_qua\T90.csv에 저장되었습니다.
# T91 그룹이 data_qua\T91.csv에 저장되었습니다.
# T92 그룹이 data_qua\T92.csv에 저장되었습니다.
# T93 그룹이 data_qua\T93.csv에 저장되었습니다.
# T94 그룹이 data_qua\T94.csv에 저장되었습니다.
# T95 그룹이 data_qua\T95.csv에 저장되었습니다.
# T96 그룹이 data_qua\T96.csv에 저장되었습니다.
# T97 그룹이 data_qua\T97.csv에 저장되었습니다.
# T98 그룹이 data_qua\T98.csv에 저장되었습니다.
# T99 그룹이 data_qua\T99.csv에 저장되었습니다.

# %%
df = pd.read_csv("./data_qua/T1.csv")
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m')  # date 값을 연월 형식의 datetime으로 변환
df
# Out:
#    series_id       date       value
# 0         T1 1979-01-01   3592.5500
# 1         T1 1979-05-01   6409.3403
# 2         T1 1979-09-01  10953.4928
# 3         T1 1980-01-01   4136.8453
# 4         T1 1980-05-01   3369.4600
# ..       ...        ...         ...
# 58        T1 1998-05-01  17469.6300
# 59        T1 1998-09-01   7672.6650
# 60        T1 1999-01-01   6407.2850
# 61        T1 1999-05-01  10330.3000
# 62        T1 1999-09-01   6995.0500
#
# [63 rows x 3 columns]

# %%
df = df.sort_values('date')

# 데이터 시각화 (예시: 'price_mean' 컬럼)
plt.figure(figsize=(12,6))
plt.plot(df['date'], df['value'], marker='o', linestyle='-', label='value')
plt.xlabel('date')
plt.ylabel('Value')
plt.title('Tourism Quarterly')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def run_stationarity_tests(series):
    print("=== ADF 검정 결과 ===")
    adf_result = adfuller(series, autolag='AIC')
    adf_stat, adf_p, adf_lags, adf_nobs, adf_crit, adf_icbest = adf_result
    print(f"검정 통계량: {adf_stat:.4f}")
    print(f"p-value: {adf_p:.4f}")
    print(f"사용된 lag 수: {adf_lags}")
    print(f"관측치 수: {adf_nobs}")
    print("임계값:")
    for key, value in adf_crit.items():
        print(f"  {key} 유의수준: {value:.4f}")
        
    # ADF 검정의 귀무가설은 "단위근이 존재하여 시계열이 비정상이다"입니다.
    # 검정 통계량이 임계값보다 작으면 귀무가설을 기각하여 정상성을 인정함.
    if adf_stat < adf_crit["5%"]:
        adf_conclusion = "정상"
        print("=> ADF 검정 결과: 귀무가설(비정상)을 기각합니다. 시계열은 정상입니다.\n")
    else:
        adf_conclusion = "비정상"
        print("=> ADF 검정 결과: 귀무가설(비정상)을 기각하지 못했습니다. 시계열은 비정상입니다.\n")
    
    print("=== KPSS 검정 결과 ===")
    kpss_result = kpss(series, regression='c', nlags="auto")
    kpss_stat, kpss_p, kpss_lags, kpss_crit = kpss_result
    print(f"검정 통계량: {kpss_stat:.4f}")
    print(f"p-value: {kpss_p:.4f}")
    print(f"사용된 lag 수: {kpss_lags}")
    print("임계값:")
    for key, value in kpss_crit.items():
        print(f"  {key} 유의수준: {value:.4f}")
        
    # KPSS 검정의 귀무가설은 "시계열이 정상이다"입니다.
    # 검정 통계량이 각 유의수준의 임계값보다 크면 귀무가설을 기각하여 비정상으로 판단합니다.
    kpss_conclusion = "정상"
    for level, crit in kpss_crit.items():
        if kpss_stat > crit:
            kpss_conclusion = "비정상"
            print(f"{level} 유의수준: KPSS 검정 통계량이 임계값보다 큽니다. (비정상)")
        else:
            print(f"{level} 유의수준: KPSS 검정 통계량이 임계값 이하입니다. (정상)")
    
    print("\n=== 종합 결과 ===")
    print(f"ADF 검정 결론: {adf_conclusion}")
    print(f"KPSS 검정 결론: {kpss_conclusion}")
    
    if adf_conclusion == "정상" and kpss_conclusion == "정상":
        print("=> 최종 결론: 시계열은 정상입니다.")
    elif adf_conclusion == "비정상" and kpss_conclusion == "비정상":
        print("=> 최종 결론: 시계열은 비정상입니다.")
    else:
        print("=> 최종 결론: 검정 결과가 상반됩니다. 추가 분석이 필요합니다.")

# 예시 사용:
series = df['value']
run_stationarity_tests(series)
# Out:
# === ADF 검정 결과 ===
# 검정 통계량: -1.4797
# p-value: 0.5435
# 사용된 lag 수: 3
# 관측치 수: 59
# 임계값:
#   1% 유의수준: -3.5464
#   5% 유의수준: -2.9119
#   10% 유의수준: -2.5937
# => ADF 검정 결과: 귀무가설(비정상)을 기각하지 못했습니다. 시계열은 비정상입니다.
#
# === KPSS 검정 결과 ===
# 검정 통계량: 0.3450
# p-value: 0.1000
# 사용된 lag 수: 30
# 임계값:
#   10% 유의수준: 0.3470
#   5% 유의수준: 0.4630
#   2.5% 유의수준: 0.5740
#   1% 유의수준: 0.7390
# 10% 유의수준: KPSS 검정 통계량이 임계값 이하입니다. (정상)
# 5% 유의수준: KPSS 검정 통계량이 임계값 이하입니다. (정상)
# 2.5% 유의수준: KPSS 검정 통계량이 임계값 이하입니다. (정상)
# 1% 유의수준: KPSS 검정 통계량이 임계값 이하입니다. (정상)
#
# === 종합 결과 ===
# ADF 검정 결론: 비정상
# KPSS 검정 결론: 정상
# => 최종 결론: 검정 결과가 상반됩니다. 추가 분석이 필요합니다.
# C:\Users\admin\AppData\Local\Temp\ipykernel_26256\3863543515.py:23: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_result = kpss(series, regression='c', nlags="auto")

# %%
# Calculate first difference
diff1 = df['value'].diff()

plt.figure(figsize=(12, 6))
plt.plot(df.index, diff1, label='First Difference', color='green')
plt.xlabel("Date")
plt.ylabel("First Difference")
plt.title("First Difference of Quarterly Count")
plt.legend()
plt.show()

# %%
# 원본 시계열 준비 (NaN 보간)
series = df['value']
series = series.interpolate()

# 1차 차분 수행 (첫 번째 값은 NaN이므로 제거)
diff1 = series.diff().dropna()

print("===== 1차 차분 후 시계열 =====")
print(diff1.head())

# ----------------------------
# Augmented Dickey-Fuller (ADF) 테스트
# ----------------------------
adf_result = adfuller(diff1)
adf_stat = adf_result[0]
adf_pvalue = adf_result[1]

print("\nADF Test Results:")
print(f"ADF Statistic: {adf_stat:.4f}")
print(f"p-value: {adf_pvalue:.4f}")
for key, value in adf_result[4].items():
    print(f"Critical Value ({key}): {value:.4f}")

# ADF 해석: p-value < 0.05이면 귀무가설(단위근 존재)을 기각하므로 정상(stationary)하다고 판단
if adf_pvalue < 0.05:
    print("ADF Test: p-value가 0.05보다 작으므로 1차 차분 시계열은 정상입니다.")
else:
    print("ADF Test: p-value가 0.05보다 크므로 1차 차분 시계열은 비정상입니다.")

# ----------------------------
# KPSS 테스트 (regression='c'는 상수 항을 가진 안정적인 시계열 가정)
# ----------------------------
def kpss_test(series, **kw):
    statistic, p_value, n_lags, critical_values = kpss(series, **kw)
    print("\nKPSS Test Results:")
    print(f"KPSS Statistic: {statistic:.4f}")
    print(f"p-value: {p_value:.4f}")
    print(f"num lags: {n_lags}")
    for key, value in critical_values.items():
        print(f"Critical Value ({key}): {value:.4f}")
    return p_value

kpss_pvalue = kpss_test(diff1, regression='c')

# KPSS 해석: KPSS의 귀무가설은 정상(stationary)임. p-value < 0.05이면 귀무가설을 기각하므로 비정상으로 판단.
if kpss_pvalue < 0.05:
    print("KPSS Test: p-value가 0.05보다 작으므로 1차 차분 시계열은 비정상입니다.")
else:
    print("KPSS Test: p-value가 0.05보다 크므로 1차 차분 시계열은 정상입니다.")
# Out:
# ===== 1차 차분 후 시계열 =====
# 1    2816.7903
# 2    4544.1525
# 3   -6816.6475
# 4    -767.3853
# 5    2076.7905
# Name: value, dtype: float64
#
# ADF Test Results:
# ADF Statistic: -38.6040
# p-value: 0.0000
# Critical Value (1%): -3.5464
# Critical Value (5%): -2.9119
# Critical Value (10%): -2.5937
# ADF Test: p-value가 0.05보다 작으므로 1차 차분 시계열은 정상입니다.
#
# KPSS Test Results:
# KPSS Statistic: 0.1042
# p-value: 0.1000
# num lags: 13
# Critical Value (10%): 0.3470
# Critical Value (5%): 0.4630
# Critical Value (2.5%): 0.5740
# Critical Value (1%): 0.7390
# KPSS Test: p-value가 0.05보다 크므로 1차 차분 시계열은 정상입니다.
# C:\Users\admin\AppData\Local\Temp\ipykernel_26256\3559260337.py:34: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   statistic, p_value, n_lags, critical_values = kpss(series, **kw)

# %%
plot_acf(df['value'], lags=50)
plt.show()

plot_pacf(df['value'], lags=31)
plt.show()

# %%
import os
import pandas as pd
import glob

# CSV 파일들이 있는 디렉토리 경로
directory = "./data_qua"

# 디렉토리 내의 모든 CSV 파일 찾기
csv_files = glob.glob(os.path.join(directory, "*.csv"))

for csv_file in csv_files:
    # CSV 파일 읽기
    df = pd.read_csv(csv_file)
    
    # 'series_id' 칼럼이 있는 경우 제거
    if 'series_id' in df.columns:
        df = df.drop(columns=['series_id'])
        # 변경된 데이터프레임을 원본 파일에 덮어쓰기 (인덱스는 저장하지 않음)
        df.to_csv(csv_file, index=False)
        print(f"Processed file: {csv_file}")
    else:
        print(f"'series_id' column not found in: {csv_file}")
# Out:
# 'series_id' column not found in: ./data_mon\T1.csv
# 'series_id' column not found in: ./data_mon\T10.csv
# 'series_id' column not found in: ./data_mon\T100.csv
# 'series_id' column not found in: ./data_mon\T101.csv
# 'series_id' column not found in: ./data_mon\T102.csv
# 'series_id' column not found in: ./data_mon\T103.csv
# 'series_id' column not found in: ./data_mon\T104.csv
# 'series_id' column not found in: ./data_mon\T105.csv
# 'series_id' column not found in: ./data_mon\T106.csv
# 'series_id' column not found in: ./data_mon\T107.csv
# 'series_id' column not found in: ./data_mon\T108.csv
# 'series_id' column not found in: ./data_mon\T109.csv
# 'series_id' column not found in: ./data_mon\T11.csv
# 'series_id' column not found in: ./data_mon\T110.csv
# 'series_id' column not found in: ./data_mon\T111.csv
# 'series_id' column not found in: ./data_mon\T112.csv
# 'series_id' column not found in: ./data_mon\T113.csv
# 'series_id' column not found in: ./data_mon\T114.csv
# 'series_id' column not found in: ./data_mon\T115.csv
# 'series_id' column not found in: ./data_mon\T116.csv
# 'series_id' column not found in: ./data_mon\T117.csv
# 'series_id' column not found in: ./data_mon\T118.csv
# 'series_id' column not found in: ./data_mon\T119.csv
# 'series_id' column not found in: ./data_mon\T12.csv
# 'series_id' column not found in: ./data_mon\T120.csv
# 'series_id' column not found in: ./data_mon\T121.csv
# 'series_id' column not found in: ./data_mon\T122.csv
# 'series_id' column not found in: ./data_mon\T123.csv
# 'series_id' column not found in: ./data_mon\T124.csv
# 'series_id' column not found in: ./data_mon\T125.csv
# 'series_id' column not found in: ./data_mon\T126.csv
# 'series_id' column not found in: ./data_mon\T127.csv
# 'series_id' column not found in: ./data_mon\T128.csv
# 'series_id' column not found in: ./data_mon\T129.csv
# 'series_id' column not found in: ./data_mon\T13.csv
# 'series_id' column not found in: ./data_mon\T130.csv
# 'series_id' column not found in: ./data_mon\T131.csv
# 'series_id' column not found in: ./data_mon\T132.csv
# 'series_id' column not found in: ./data_mon\T133.csv
# 'series_id' column not found in: ./data_mon\T134.csv
# 'series_id' column not found in: ./data_mon\T135.csv
# 'series_id' column not found in: ./data_mon\T136.csv
# 'series_id' column not found in: ./data_mon\T137.csv
# 'series_id' column not found in: ./data_mon\T138.csv
# 'series_id' column not found in: ./data_mon\T139.csv
# 'series_id' column not found in: ./data_mon\T87.csv
# 'series_id' column not found in: ./data_mon\T88.csv
# 'series_id' column not found in: ./data_mon\T89.csv
# 'series_id' column not found in: ./data_mon\T9.csv
# 'series_id' column not found in: ./data_mon\T90.csv
# 'series_id' column not found in: ./data_mon\T91.csv
# 'series_id' column not found in: ./data_mon\T92.csv
# 'series_id' column not found in: ./data_mon\T93.csv
# 'series_id' column not found in: ./data_mon\T94.csv
# 'series_id' column not found in: ./data_mon\T95.csv
# 'series_id' column not found in: ./data_mon\T96.csv
# 'series_id' column not found in: ./data_mon\T97.csv
# 'series_id' column not found in: ./data_mon\T98.csv
# 'series_id' column not found in: ./data_mon\T99.csv

# %%
import os
import glob
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pmdarima as pm
from sklearn.metrics import mean_absolute_error, mean_squared_error

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", message="No frequency information was provided, so inferred frequency D will be used.")
warnings.filterwarnings("ignore", message="Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.")
warnings.filterwarnings("ignore", message="Non-invertible starting MA parameters found. Using zeros as starting parameters.")
warnings.filterwarnings("ignore", category=RuntimeWarning, message="Mean of empty slice")

# ----------------------------
# 1. 데이터 전처리 (로그 변환 + 스무딩 + Min–Max Scaling)
# ----------------------------
def log_smooth_scale_series(series, window=12):
    """
    로그 변환, 이동평균 스무딩, 그리고 Min–Max Scaling을 적용.
    반환값:
      - scaled_series: 스케일된 시계열 (0~1 범위)
      - scale_min: 스무딩된 로그 시계열의 최소값 (역변환에 사용)
      - scale_max: 스무딩된 로그 시계열의 최대값 (역변환에 사용)
    """
    # 로그 변환 (음수 방지)
    log_series = np.log1p(series)
    # 이동평균 스무딩
    smoothed_series = log_series.rolling(window=window, min_periods=1).mean()
    # Min–Max Scaling
    scale_min = smoothed_series.min()
    scale_max = smoothed_series.max()
    scaled_series = (smoothed_series - scale_min) / (scale_max - scale_min)
    return scaled_series, scale_min, scale_max

# 예시: 데이터프레임 df에 'price_mean' 칼럼이 있다고 가정합니다.
# (실제 코드 적용 시 df를 올바르게 로드해주세요.)
series = df['value']
series = series.interpolate()

# 전처리: 로그 변환, 스무딩, 그리고 스케일링 (예: window=6 → 6시간 이동평균)
window_size = 1
scaled_series, scale_min, scale_max = log_smooth_scale_series(series, window=window_size)

# ----------------------------
# 2. 데이터 분할 (80:20)
# ----------------------------
split_index = int(len(scaled_series) * 0.8)
train_scaled = scaled_series.iloc[:split_index]
test_scaled  = scaled_series.iloc[split_index:]
# 원본 시계열 분할 (평가용)
train_original = series.iloc[:split_index]
test_original  = series.iloc[split_index:]
horizon = len(test_scaled)

# ----------------------------
# 3. 평가 지표 계산 함수
# ----------------------------
def evaluate_forecast(actual, forecast, eps=1e-8):
    mae = mean_absolute_error(actual, forecast)
    rmse = np.sqrt(mean_squared_error(actual, forecast))
    
    diff_actual = np.abs(np.diff(actual))
    scale = np.mean(diff_actual) if np.mean(diff_actual) != 0 else eps
    mase = mae / scale
    
    denom = (np.abs(actual) + np.abs(forecast)) / 2
    smape = 100 * np.mean(np.abs(forecast - actual) / np.where(denom == 0, eps, denom))
    
    msape = 100 * np.median(np.abs(forecast - actual) / np.where(actual == 0, eps, actual))
    
    return {"MAE": mae, "RMSE": rmse, "MASE": mase, "sMAPE": smape, "msAPE": msape}

# ----------------------------
# 4. 모델 학습 및 예측 (학습 데이터로 fit, 테스트 구간 예측)
# ----------------------------
# 비정상 시계열과 주기성(주기: 4)를 반영하여 seasonal=True, m=4로 설정합니다.
model = pm.auto_arima(train_scaled, seasonal=True, m=12, stepwise=True, trace=True,
                        error_action='ignore', suppress_warnings=True)
print(model.summary())

# 테스트 데이터 길이(horizon)만큼 예측
forecast_scaled, conf_int_scaled = model.predict(n_periods=horizon, return_conf_int=True)
# 예측 결과의 index는 테스트 데이터와 동일하게 설정
forecast_series_scaled = pd.Series(forecast_scaled, index=test_scaled.index)

# ----------------------------
# 5. 역변환: 스케일 복원 후 역 로그 변환
# ----------------------------
# 역 스케일링: 원래의 스무딩된 로그값 복원
forecast_series_log = forecast_series_scaled * (scale_max - scale_min) + scale_min
conf_int_log = np.column_stack(( 
    conf_int_scaled[:, 0] * (scale_max - scale_min) + scale_min,
    conf_int_scaled[:, 1] * (scale_max - scale_min) + scale_min
))
# 역 로그 변환: np.expm1로 복원
forecast_series_final = np.expm1(forecast_series_log)
conf_int_final = np.column_stack((
    np.expm1(conf_int_log[:, 0]),
    np.expm1(conf_int_log[:, 1])
))

# ----------------------------
# 6. 평가 수행
# ----------------------------
metrics = evaluate_forecast(test_original, forecast_series_final)
print("Evaluation Metrics:", metrics)

# ----------------------------
# 7. 결과 시각화 (원본 데이터 기준)
# ----------------------------
plt.figure(figsize=(12, 6))
# 원본 데이터 플롯 (price_mean)
plt.plot(series.index, series, label='Observed', alpha=0.7)
# 예측 결과 플롯 (역변환된 값)
plt.plot(forecast_series_final.index, forecast_series_final, label='Forecast', color='red', linestyle='-')
# 신뢰 구간 플롯
plt.figure(figsize=(12, 6))
plt.plot(series.index, series, label='Observed', alpha=0.7)
plt.plot(forecast_series_final.index, forecast_series_final, label='Forecast', color='red', linestyle='-')
plt.fill_between(forecast_series_final.index,
                 conf_int_final[:, 0],
                 conf_int_final[:, 1],
                 color='pink', alpha=0.3, label='Confidence Interval')
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("ARIMA Forecast on Non-stationary Data with Seasonality (m=4)")

# y축 범위를 실제 데이터의 5~95 백분위수로 제한 (필요에 따라 조정 가능)
lower_limit = np.percentile(series, 5)
upper_limit = np.percentile(series, 95)
plt.ylim(lower_limit, upper_limit)

plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-744.570, Time=1.65 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-581.806, Time=0.09 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-695.437, Time=0.36 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-714.304, Time=0.43 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-583.386, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=-713.082, Time=1.06 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=-732.080, Time=1.09 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=-742.941, Time=2.08 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=-743.133, Time=1.36 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=-682.224, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=-730.619, Time=1.73 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=-743.526, Time=1.85 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=-740.391, Time=2.78 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=-746.675, Time=1.36 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=-715.057, Time=1.39 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=-733.541, Time=1.06 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=-744.410, Time=1.37 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=-744.582, Time=2.58 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=-684.190, Time=0.78 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=-732.249, Time=1.03 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=-745.035, Time=2.02 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=-741.585, Time=1.76 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=-748.550, Time=0.79 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=-716.746, Time=0.66 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=-735.415, Time=0.86 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=-745.713, Time=0.43 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=-746.913, Time=2.00 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=-684.314, Time=0.29 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=-734.358, Time=1.39 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=-747.295, Time=1.85 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=-744.762, Time=2.41 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=-747.757, Time=1.02 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=-746.604, Time=1.50 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=-748.947, Time=1.65 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=-716.954, Time=0.75 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=-735.971, Time=1.35 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=-746.956, Time=2.14 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=-747.155, Time=1.53 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-683.857, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=-734.585, Time=1.58 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=-747.534, Time=1.53 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=-745.185, Time=3.16 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=-710.143, Time=0.69 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=-747.282, Time=1.40 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=-665.452, Time=0.64 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=-728.563, Time=1.46 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=-749.876, Time=1.06 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=-712.219, Time=0.53 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=-734.332, Time=0.71 sec
#  ARIMA(1,1,1)(2,0,1)[12]             : AIC=-747.876, Time=2.21 sec
#  ARIMA(1,1,1)(1,0,2)[12]             : AIC=-747.876, Time=1.83 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=-676.450, Time=0.21 sec
#  ARIMA(1,1,1)(0,0,2)[12]             : AIC=-732.404, Time=1.28 sec
#  ARIMA(1,1,1)(2,0,0)[12]             : AIC=-747.608, Time=1.08 sec
#  ARIMA(1,1,1)(2,0,2)[12]             : AIC=-745.969, Time=1.53 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=-748.770, Time=0.35 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=-711.915, Time=0.31 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=-747.922, Time=0.69 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=-747.851, Time=0.73 sec
#  ARIMA(0,1,0)(1,0,1)[12]             : AIC=-667.325, Time=0.35 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=-749.738, Time=0.91 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=-730.179, Time=0.70 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=-745.876, Time=1.16 sec
#
# Best model:  ARIMA(1,1,1)(1,0,1)[12]
# Total fit time: 75.013 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  264
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood                 379.938
# Date:                            Mon, 17 Mar 2025   AIC                           -749.876
# Time:                                    10:12:51   BIC                           -732.015
# Sample:                                         0   HQIC                          -742.698
#                                             - 264
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1603      0.086      1.859      0.063      -0.009       0.329
# ma.L1         -0.7876      0.054    -14.546      0.000      -0.894      -0.681
# ar.S.L12       0.8577      0.054     15.826      0.000       0.751       0.964
# ma.S.L12      -0.5358      0.089     -6.026      0.000      -0.710      -0.362
# sigma2         0.0032      0.000     12.496      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 8.35
# Prob(Q):                              0.90   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.38   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Evaluation Metrics: {'MAE': 2351.1806414171256, 'RMSE': 2737.640685218052, 'MASE': 1.6429979648033495, 'sMAPE': 51.35479094782691, 'msAPE': 83.55376066264257}

# %%
import os
import pandas as pd
import numpy as np
import time
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# ----------------------------
# Model Libraries
# ----------------------------
# ARIMA: SARIMAX from statsmodels
from statsmodels.tsa.statespace.sarimax import SARIMAX
# SES and ETS: SimpleExpSmoothing and ExponentialSmoothing from statsmodels
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, ExponentialSmoothing
# Prophet
from prophet import Prophet
# TBATS from tbats package
try:
    from tbats import TBATS
except Exception as e:
    print("TBATS 라이브러리가 설치되어 있지 않습니다.", e)
# Theta: from statsforecast
try:
    from statsforecast.models import Theta
    from statsforecast import StatsForecast
except Exception as e:
    print("Theta 모델 관련 라이브러리가 설치되어 있지 않습니다.", e)

# ----------------------------
# Evaluation Metric Functions
# ----------------------------
def calc_smape(actual, forecast, eps=1e-8):
    """Symmetric Mean Absolute Percentage Error"""
    return 100 * np.mean(2 * np.abs(forecast - actual) / (np.abs(actual) + np.abs(forecast) + eps))

def calc_mase(actual, forecast, train, eps=1e-8):
    """Mean Absolute Scaled Error using naive forecast (lag=1) for scaling"""
    mae = mean_absolute_error(actual, forecast)
    naive = train.shift(1)
    scale = np.mean(np.abs(train.dropna() - naive.dropna()))
    return mae / (scale + eps)

# ----------------------------
# 설정: CSV 파일들이 들어 있는 폴더 경로 (월간 데이터)
# ----------------------------
input_folder = "./data_mon"  # 실제 경로로 수정

# 결과를 저장할 리스트 (각 파일의 모델별 평가 결과 누적)
all_results = []

# ----------------------------
# 폴더 내의 각 CSV 파일 처리
# ----------------------------
for file in os.listdir(input_folder):
    if not file.endswith(".csv"):
        continue
    file_path = os.path.join(input_folder, file)
    
    try:
        # CSV 파일 읽기 (첫 번째 컬럼이 날짜 인덱스라고 가정)
        df_file = pd.read_csv(file_path, parse_dates=True, index_col=0)
    except Exception as e:
        print(f"{file} 읽기 에러: {e}")
        continue

    if 'value' not in df_file.columns:
        print(f"{file} 스킵: 'value' 컬럼 없음")
        continue

    # 인덱스를 datetime으로 강제 변환
    df_file.index = pd.to_datetime(df_file.index)
    
    # 타겟 시계열: value
    series = df_file['value'].dropna()
    if series.empty:
        print(f"{file} 스킵: 시계열 데이터가 비어 있음")
        continue

    # ----------------------------
    # 데이터 분할: 80% 학습, 20% 테스트
    # ----------------------------
    n_total = len(series)
    split_index = int(n_total * 0.8)
    train_series = series.iloc[:split_index]
    test_series = series.iloc[split_index:]
    horizon = len(test_series)
    actual = test_series.copy()
    
    # MASE 계산을 위한 scale: training 데이터의 naive forecast (lag=1)
    naive_forecast = train_series.shift(1)
    scale = np.mean(np.abs(train_series.dropna() - naive_forecast.dropna()))
    
    file_results = []  # 파일별 모델 평가 결과 저장 리스트

    # ----------------------------
    # Model 1: ARIMA (ARMA) using SARIMAX
    # 비정상 시계열 예측용으로 d=1, seasonal_order=(0,1,1,12) 사용 (주기가 12)
    # ----------------------------
    try:
        start = time.time()
        model_arima = SARIMAX(train_series, order=(1,1,1), seasonal_order=(0,1,1,4))
        fit_arima = model_arima.fit(disp=False)
        forecast_arima = fit_arima.forecast(steps=horizon)
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_arima)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_arima))
        smape_val = calc_smape(actual.values, forecast_arima.values)
        mase_val = calc_mase(actual, forecast_arima, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'ARIMA',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - ARIMA 완료")
    except Exception as e:
        print(f"{file} - ARIMA 모델 에러: {e}")
    
    # ----------------------------
    # Model 2: SES using SimpleExpSmoothing
    # ----------------------------
    try:
        start = time.time()
        model_ses = SimpleExpSmoothing(train_series).fit(optimized=True)
        forecast_ses = model_ses.forecast(steps=horizon)
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_ses)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_ses))
        smape_val = calc_smape(actual.values, forecast_ses.values)
        mase_val = calc_mase(actual, forecast_ses, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'SES',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - SES 완료")
    except Exception as e:
        print(f"{file} - SES 모델 에러: {e}")
    
    # ----------------------------
    # Model 3: Theta using statsforecast
    # ----------------------------
    try:
        start = time.time()
        train_df = pd.DataFrame({
            'ds': train_series.index, 
            'y': train_series.values, 
            'unique_id': 'series'
        })
        sf = StatsForecast(train_df, models=[Theta()], freq='M')
        forecast_df = sf.forecast(horizon, train_df)
        forecast_theta = forecast_df['Theta']
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_theta)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_theta))
        smape_val = calc_smape(actual.values, forecast_theta.values)
        mase_val = calc_mase(actual, forecast_theta, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'Theta',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - Theta 완료")
    except Exception as e:
        print(f"{file} - Theta 모델 에러: {e}")
    
    # ----------------------------
    # Model 4: TBATS using tbats package
    # ----------------------------
    # try:
    #     start = time.time()
    #     # 데이터에 특별한 계절성이 없다고 가정하여 seasonal_periods 빈 리스트 사용
    #     estimator = TBATS(seasonal_periods=[])
    #     model_tbats = estimator.fit(train_series.values)
    #     forecast_tbats = model_tbats.forecast(steps=horizon)
    #     forecast_tbats = pd.Series(forecast_tbats, index=test_series.index)
    #     end = time.time()
    #     exec_time = end - start
    # 
    #     mae_val = mean_absolute_error(actual, forecast_tbats)
    #     rmse_val = np.sqrt(mean_squared_error(actual, forecast_tbats))
    #     smape_val = calc_smape(actual.values, forecast_tbats.values)
    #     mase_val = calc_mase(actual, forecast_tbats, train_series)
    #     
    #     file_results.append({
    #         'File': file,
    #         'Model': 'TBATS',
    #         'sMAPE': smape_val,
    #         'MASE': mase_val,
    #         'MAE': mae_val,
    #         'RMSE': rmse_val,
    #         'Execution Time': exec_time
    #     })
    #     print(f"{file} - TBATS 완료")
    # except Exception as e:
    #     print(f"{file} - TBATS 모델 에러: {e}")
    
    # ----------------------------
    # Model 5: ETS using ExponentialSmoothing
    # ----------------------------
    try:
        start = time.time()
        # 비정상 시계열 예측을 위해 additive 추세와 계절성을 사용 (seasonal_periods=12)
        model_ets = ExponentialSmoothing(train_series, trend='add', seasonal='add', seasonal_periods=4).fit(optimized=True)
        forecast_ets = model_ets.forecast(steps=horizon)
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_ets)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_ets))
        smape_val = calc_smape(actual.values, forecast_ets.values)
        mase_val = calc_mase(actual, forecast_ets, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'ETS',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - ETS 완료")
    except Exception as e:
        print(f"{file} - ETS 모델 에러: {e}")
    
    # ----------------------------
    # Model 6: Prophet
    # ----------------------------
    try:
        start = time.time()
        train_prophet = pd.DataFrame({
            'ds': train_series.index, 
            'y': train_series.values
        })
        # Prophet은 ds에 타임존 정보가 있으면 에러 발생하므로 제거
        train_prophet['ds'] = pd.to_datetime(train_prophet['ds']).dt.tz_localize(None)
        model_prophet = Prophet()
        model_prophet.fit(train_prophet)
        future = model_prophet.make_future_dataframe(periods=horizon, freq='M', include_history=False)
        future['ds'] = pd.to_datetime(future['ds']).dt.tz_localize(None)
        forecast_prophet = model_prophet.predict(future)
        forecast_prophet = pd.Series(forecast_prophet['yhat'].values, index=test_series.index)
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_prophet)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_prophet))
        smape_val = calc_smape(actual.values, forecast_prophet.values)
        mase_val = calc_mase(actual, forecast_prophet, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'Prophet',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - Prophet 완료")
    except Exception as e:
        print(f"{file} - Prophet 모델 에러: {e}")
    
    # 파일별 결과를 전체 결과 리스트에 추가
    for res in file_results:
        res['File'] = file  # 파일 이름 추가
    all_results.extend(file_results)

# ----------------------------
# 전체 데이터셋에 대한 모델별 평균 평가 지표 계산
# ----------------------------
results_df = pd.DataFrame(all_results)
if not results_df.empty:
    avg_results = results_df.drop(columns=['File']).groupby('Model').mean().reset_index()
    avg_results.to_csv("data_qua_forecast_evaluation_avg_metrics.csv", index=False)
    print("전체 데이터셋에 대한 평균 평가 지표가 'data_qua_forecast_evaluation_avg_metrics.csv'에 저장되었습니다.")
    print(avg_results)
else:
    print("평가 결과가 없습니다.")
