# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller, kpss
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df = pd.read_csv("./ori/preprocessed_monthly_data.csv")
df
# Out:
#        series_id     date      value
# 0             T1  1979-01  1149.8700
# 1             T1  1979-02  1053.8002
# 2             T1  1979-03  1388.8798
# 3             T1  1979-04  1783.3702
# 4             T1  1979-05  1921.0252
# ...          ...      ...        ...
# 109275      T366  2000-08  7778.0000
# 109276      T366  2000-09  7859.0000
# 109277      T366  2000-10  4802.0000
# 109278      T366  2000-11  2426.0000
# 109279      T366  2000-12   637.0000
#
# [109280 rows x 3 columns]

# %%
# 저장할 폴더 경로
output_folder = "data_mon"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# DataFrame df를 "series_id" 컬럼 기준으로 그룹화 후 각 그룹을 CSV 파일로 저장
for series_id, group in df.groupby('series_id'):
    file_name = f"{series_id}.csv"  # 예: T1.csv, T2.csv, ...
    file_path = os.path.join(output_folder, file_name)
    group.to_csv(file_path, index=False)
    print(f"{series_id} 그룹이 {file_path}에 저장되었습니다.")
# Out:
# T1 그룹이 data_mon\T1.csv에 저장되었습니다.
# T10 그룹이 data_mon\T10.csv에 저장되었습니다.
# T100 그룹이 data_mon\T100.csv에 저장되었습니다.
# T101 그룹이 data_mon\T101.csv에 저장되었습니다.
# T102 그룹이 data_mon\T102.csv에 저장되었습니다.
# T103 그룹이 data_mon\T103.csv에 저장되었습니다.
# T104 그룹이 data_mon\T104.csv에 저장되었습니다.
# T105 그룹이 data_mon\T105.csv에 저장되었습니다.
# T106 그룹이 data_mon\T106.csv에 저장되었습니다.
# T107 그룹이 data_mon\T107.csv에 저장되었습니다.
# T108 그룹이 data_mon\T108.csv에 저장되었습니다.
# T109 그룹이 data_mon\T109.csv에 저장되었습니다.
# T11 그룹이 data_mon\T11.csv에 저장되었습니다.
# T110 그룹이 data_mon\T110.csv에 저장되었습니다.
# T111 그룹이 data_mon\T111.csv에 저장되었습니다.
# T112 그룹이 data_mon\T112.csv에 저장되었습니다.
# T113 그룹이 data_mon\T113.csv에 저장되었습니다.
# T114 그룹이 data_mon\T114.csv에 저장되었습니다.
# T115 그룹이 data_mon\T115.csv에 저장되었습니다.
# T116 그룹이 data_mon\T116.csv에 저장되었습니다.
# T117 그룹이 data_mon\T117.csv에 저장되었습니다.
# T118 그룹이 data_mon\T118.csv에 저장되었습니다.
# T119 그룹이 data_mon\T119.csv에 저장되었습니다.
# T12 그룹이 data_mon\T12.csv에 저장되었습니다.
# T120 그룹이 data_mon\T120.csv에 저장되었습니다.
# T121 그룹이 data_mon\T121.csv에 저장되었습니다.
# T122 그룹이 data_mon\T122.csv에 저장되었습니다.
# T123 그룹이 data_mon\T123.csv에 저장되었습니다.
# T124 그룹이 data_mon\T124.csv에 저장되었습니다.
# T125 그룹이 data_mon\T125.csv에 저장되었습니다.
# T126 그룹이 data_mon\T126.csv에 저장되었습니다.
# T127 그룹이 data_mon\T127.csv에 저장되었습니다.
# T128 그룹이 data_mon\T128.csv에 저장되었습니다.
# T129 그룹이 data_mon\T129.csv에 저장되었습니다.
# T13 그룹이 data_mon\T13.csv에 저장되었습니다.
# T130 그룹이 data_mon\T130.csv에 저장되었습니다.
# T131 그룹이 data_mon\T131.csv에 저장되었습니다.
# T132 그룹이 data_mon\T132.csv에 저장되었습니다.
# T133 그룹이 data_mon\T133.csv에 저장되었습니다.
# T134 그룹이 data_mon\T134.csv에 저장되었습니다.
# T135 그룹이 data_mon\T135.csv에 저장되었습니다.
# T136 그룹이 data_mon\T136.csv에 저장되었습니다.
# T137 그룹이 data_mon\T137.csv에 저장되었습니다.
# T138 그룹이 data_mon\T138.csv에 저장되었습니다.
# T139 그룹이 data_mon\T139.csv에 저장되었습니다.
# T14 그룹이 data_mon\T14.csv에 저장되었습니다.
# T140 그룹이 data_mon\T140.csv에 저장되었습니다.
# T141 그룹이 data_mon\T141.csv에 저장되었습니다.
# T142 그룹이 data_mon\T142.csv에 저장되었습니다.
# T143 그룹이 data_mon\T143.csv에 저장되었습니다.
# T144 그룹이 data_mon\T144.csv에 저장되었습니다.
# T145 그룹이 data_mon\T145.csv에 저장되었습니다.
# T146 그룹이 data_mon\T146.csv에 저장되었습니다.
# T147 그룹이 data_mon\T147.csv에 저장되었습니다.
# T148 그룹이 data_mon\T148.csv에 저장되었습니다.
# T149 그룹이 data_mon\T149.csv에 저장되었습니다.
# T15 그룹이 data_mon\T15.csv에 저장되었습니다.
# T150 그룹이 data_mon\T150.csv에 저장되었습니다.
# T151 그룹이 data_mon\T151.csv에 저장되었습니다.
# T152 그룹이 data_mon\T152.csv에 저장되었습니다.
# T153 그룹이 data_mon\T153.csv에 저장되었습니다.
# T154 그룹이 data_mon\T154.csv에 저장되었습니다.
# T155 그룹이 data_mon\T155.csv에 저장되었습니다.
# T156 그룹이 data_mon\T156.csv에 저장되었습니다.
# T157 그룹이 data_mon\T157.csv에 저장되었습니다.
# T158 그룹이 data_mon\T158.csv에 저장되었습니다.
# T159 그룹이 data_mon\T159.csv에 저장되었습니다.
# T16 그룹이 data_mon\T16.csv에 저장되었습니다.
# T160 그룹이 data_mon\T160.csv에 저장되었습니다.
# T161 그룹이 data_mon\T161.csv에 저장되었습니다.
# T162 그룹이 data_mon\T162.csv에 저장되었습니다.
# T163 그룹이 data_mon\T163.csv에 저장되었습니다.
# T164 그룹이 data_mon\T164.csv에 저장되었습니다.
# T165 그룹이 data_mon\T165.csv에 저장되었습니다.
# T166 그룹이 data_mon\T166.csv에 저장되었습니다.
# T167 그룹이 data_mon\T167.csv에 저장되었습니다.
# T168 그룹이 data_mon\T168.csv에 저장되었습니다.
# T169 그룹이 data_mon\T169.csv에 저장되었습니다.
# T17 그룹이 data_mon\T17.csv에 저장되었습니다.
# T170 그룹이 data_mon\T170.csv에 저장되었습니다.
# T171 그룹이 data_mon\T171.csv에 저장되었습니다.
# T172 그룹이 data_mon\T172.csv에 저장되었습니다.
# T173 그룹이 data_mon\T173.csv에 저장되었습니다.
# T174 그룹이 data_mon\T174.csv에 저장되었습니다.
# T175 그룹이 data_mon\T175.csv에 저장되었습니다.
# T176 그룹이 data_mon\T176.csv에 저장되었습니다.
# T177 그룹이 data_mon\T177.csv에 저장되었습니다.
# T178 그룹이 data_mon\T178.csv에 저장되었습니다.
# T179 그룹이 data_mon\T179.csv에 저장되었습니다.
# T18 그룹이 data_mon\T18.csv에 저장되었습니다.
# T180 그룹이 data_mon\T180.csv에 저장되었습니다.
# T181 그룹이 data_mon\T181.csv에 저장되었습니다.
# T182 그룹이 data_mon\T182.csv에 저장되었습니다.
# T183 그룹이 data_mon\T183.csv에 저장되었습니다.
# T184 그룹이 data_mon\T184.csv에 저장되었습니다.
# T185 그룹이 data_mon\T185.csv에 저장되었습니다.
# T186 그룹이 data_mon\T186.csv에 저장되었습니다.
# T187 그룹이 data_mon\T187.csv에 저장되었습니다.
# T188 그룹이 data_mon\T188.csv에 저장되었습니다.
# T189 그룹이 data_mon\T189.csv에 저장되었습니다.
# T19 그룹이 data_mon\T19.csv에 저장되었습니다.
# T190 그룹이 data_mon\T190.csv에 저장되었습니다.
# T191 그룹이 data_mon\T191.csv에 저장되었습니다.
# T192 그룹이 data_mon\T192.csv에 저장되었습니다.
# T193 그룹이 data_mon\T193.csv에 저장되었습니다.
# T194 그룹이 data_mon\T194.csv에 저장되었습니다.
# T195 그룹이 data_mon\T195.csv에 저장되었습니다.
# T196 그룹이 data_mon\T196.csv에 저장되었습니다.
# T197 그룹이 data_mon\T197.csv에 저장되었습니다.
# T198 그룹이 data_mon\T198.csv에 저장되었습니다.
# T199 그룹이 data_mon\T199.csv에 저장되었습니다.
# T2 그룹이 data_mon\T2.csv에 저장되었습니다.
# T20 그룹이 data_mon\T20.csv에 저장되었습니다.
# T200 그룹이 data_mon\T200.csv에 저장되었습니다.
# T201 그룹이 data_mon\T201.csv에 저장되었습니다.
# T202 그룹이 data_mon\T202.csv에 저장되었습니다.
# T203 그룹이 data_mon\T203.csv에 저장되었습니다.
# T204 그룹이 data_mon\T204.csv에 저장되었습니다.
# T205 그룹이 data_mon\T205.csv에 저장되었습니다.
# T206 그룹이 data_mon\T206.csv에 저장되었습니다.
# T207 그룹이 data_mon\T207.csv에 저장되었습니다.
# T208 그룹이 data_mon\T208.csv에 저장되었습니다.
# T209 그룹이 data_mon\T209.csv에 저장되었습니다.
# T21 그룹이 data_mon\T21.csv에 저장되었습니다.
# T210 그룹이 data_mon\T210.csv에 저장되었습니다.
# T211 그룹이 data_mon\T211.csv에 저장되었습니다.
# T212 그룹이 data_mon\T212.csv에 저장되었습니다.
# T213 그룹이 data_mon\T213.csv에 저장되었습니다.
# T214 그룹이 data_mon\T214.csv에 저장되었습니다.
# T215 그룹이 data_mon\T215.csv에 저장되었습니다.
# T216 그룹이 data_mon\T216.csv에 저장되었습니다.
# T217 그룹이 data_mon\T217.csv에 저장되었습니다.
# T218 그룹이 data_mon\T218.csv에 저장되었습니다.
# T219 그룹이 data_mon\T219.csv에 저장되었습니다.
# T22 그룹이 data_mon\T22.csv에 저장되었습니다.
# T220 그룹이 data_mon\T220.csv에 저장되었습니다.
# T221 그룹이 data_mon\T221.csv에 저장되었습니다.
# T222 그룹이 data_mon\T222.csv에 저장되었습니다.
# T223 그룹이 data_mon\T223.csv에 저장되었습니다.
# T224 그룹이 data_mon\T224.csv에 저장되었습니다.
# T225 그룹이 data_mon\T225.csv에 저장되었습니다.
# T226 그룹이 data_mon\T226.csv에 저장되었습니다.
# T227 그룹이 data_mon\T227.csv에 저장되었습니다.
# T228 그룹이 data_mon\T228.csv에 저장되었습니다.
# T229 그룹이 data_mon\T229.csv에 저장되었습니다.
# T23 그룹이 data_mon\T23.csv에 저장되었습니다.
# T230 그룹이 data_mon\T230.csv에 저장되었습니다.
# T231 그룹이 data_mon\T231.csv에 저장되었습니다.
# T232 그룹이 data_mon\T232.csv에 저장되었습니다.
# T233 그룹이 data_mon\T233.csv에 저장되었습니다.
# T234 그룹이 data_mon\T234.csv에 저장되었습니다.
# T235 그룹이 data_mon\T235.csv에 저장되었습니다.
# T236 그룹이 data_mon\T236.csv에 저장되었습니다.
# T237 그룹이 data_mon\T237.csv에 저장되었습니다.
# T238 그룹이 data_mon\T238.csv에 저장되었습니다.
# T239 그룹이 data_mon\T239.csv에 저장되었습니다.
# T24 그룹이 data_mon\T24.csv에 저장되었습니다.
# T240 그룹이 data_mon\T240.csv에 저장되었습니다.
# T241 그룹이 data_mon\T241.csv에 저장되었습니다.
# T242 그룹이 data_mon\T242.csv에 저장되었습니다.
# T243 그룹이 data_mon\T243.csv에 저장되었습니다.
# T244 그룹이 data_mon\T244.csv에 저장되었습니다.
# T245 그룹이 data_mon\T245.csv에 저장되었습니다.
# T246 그룹이 data_mon\T246.csv에 저장되었습니다.
# T247 그룹이 data_mon\T247.csv에 저장되었습니다.
# T248 그룹이 data_mon\T248.csv에 저장되었습니다.
# T249 그룹이 data_mon\T249.csv에 저장되었습니다.
# T25 그룹이 data_mon\T25.csv에 저장되었습니다.
# T250 그룹이 data_mon\T250.csv에 저장되었습니다.
# T251 그룹이 data_mon\T251.csv에 저장되었습니다.
# T252 그룹이 data_mon\T252.csv에 저장되었습니다.
# T253 그룹이 data_mon\T253.csv에 저장되었습니다.
# T254 그룹이 data_mon\T254.csv에 저장되었습니다.
# T255 그룹이 data_mon\T255.csv에 저장되었습니다.
# T256 그룹이 data_mon\T256.csv에 저장되었습니다.
# T257 그룹이 data_mon\T257.csv에 저장되었습니다.
# T258 그룹이 data_mon\T258.csv에 저장되었습니다.
# T259 그룹이 data_mon\T259.csv에 저장되었습니다.
# T26 그룹이 data_mon\T26.csv에 저장되었습니다.
# T260 그룹이 data_mon\T260.csv에 저장되었습니다.
# T261 그룹이 data_mon\T261.csv에 저장되었습니다.
# T262 그룹이 data_mon\T262.csv에 저장되었습니다.
# T263 그룹이 data_mon\T263.csv에 저장되었습니다.
# T264 그룹이 data_mon\T264.csv에 저장되었습니다.
# T265 그룹이 data_mon\T265.csv에 저장되었습니다.
# T266 그룹이 data_mon\T266.csv에 저장되었습니다.
# T267 그룹이 data_mon\T267.csv에 저장되었습니다.
# T268 그룹이 data_mon\T268.csv에 저장되었습니다.
# T269 그룹이 data_mon\T269.csv에 저장되었습니다.
# T27 그룹이 data_mon\T27.csv에 저장되었습니다.
# T270 그룹이 data_mon\T270.csv에 저장되었습니다.
# T271 그룹이 data_mon\T271.csv에 저장되었습니다.
# T272 그룹이 data_mon\T272.csv에 저장되었습니다.
# T273 그룹이 data_mon\T273.csv에 저장되었습니다.
# T274 그룹이 data_mon\T274.csv에 저장되었습니다.
# T275 그룹이 data_mon\T275.csv에 저장되었습니다.
# T276 그룹이 data_mon\T276.csv에 저장되었습니다.
# T277 그룹이 data_mon\T277.csv에 저장되었습니다.
# T278 그룹이 data_mon\T278.csv에 저장되었습니다.
# T279 그룹이 data_mon\T279.csv에 저장되었습니다.
# T28 그룹이 data_mon\T28.csv에 저장되었습니다.
# T280 그룹이 data_mon\T280.csv에 저장되었습니다.
# T281 그룹이 data_mon\T281.csv에 저장되었습니다.
# T282 그룹이 data_mon\T282.csv에 저장되었습니다.
# T283 그룹이 data_mon\T283.csv에 저장되었습니다.
# T284 그룹이 data_mon\T284.csv에 저장되었습니다.
# T285 그룹이 data_mon\T285.csv에 저장되었습니다.
# T286 그룹이 data_mon\T286.csv에 저장되었습니다.
# T287 그룹이 data_mon\T287.csv에 저장되었습니다.
# T288 그룹이 data_mon\T288.csv에 저장되었습니다.
# T289 그룹이 data_mon\T289.csv에 저장되었습니다.
# T29 그룹이 data_mon\T29.csv에 저장되었습니다.
# T290 그룹이 data_mon\T290.csv에 저장되었습니다.
# T291 그룹이 data_mon\T291.csv에 저장되었습니다.
# T292 그룹이 data_mon\T292.csv에 저장되었습니다.
# T293 그룹이 data_mon\T293.csv에 저장되었습니다.
# T294 그룹이 data_mon\T294.csv에 저장되었습니다.
# T295 그룹이 data_mon\T295.csv에 저장되었습니다.
# T296 그룹이 data_mon\T296.csv에 저장되었습니다.
# T297 그룹이 data_mon\T297.csv에 저장되었습니다.
# T298 그룹이 data_mon\T298.csv에 저장되었습니다.
# T299 그룹이 data_mon\T299.csv에 저장되었습니다.
# T3 그룹이 data_mon\T3.csv에 저장되었습니다.
# T30 그룹이 data_mon\T30.csv에 저장되었습니다.
# T300 그룹이 data_mon\T300.csv에 저장되었습니다.
# T301 그룹이 data_mon\T301.csv에 저장되었습니다.
# T302 그룹이 data_mon\T302.csv에 저장되었습니다.
# T303 그룹이 data_mon\T303.csv에 저장되었습니다.
# T304 그룹이 data_mon\T304.csv에 저장되었습니다.
# T305 그룹이 data_mon\T305.csv에 저장되었습니다.
# T306 그룹이 data_mon\T306.csv에 저장되었습니다.
# T307 그룹이 data_mon\T307.csv에 저장되었습니다.
# T308 그룹이 data_mon\T308.csv에 저장되었습니다.
# T309 그룹이 data_mon\T309.csv에 저장되었습니다.
# T31 그룹이 data_mon\T31.csv에 저장되었습니다.
# T310 그룹이 data_mon\T310.csv에 저장되었습니다.
# T311 그룹이 data_mon\T311.csv에 저장되었습니다.
# T312 그룹이 data_mon\T312.csv에 저장되었습니다.
# T313 그룹이 data_mon\T313.csv에 저장되었습니다.
# T314 그룹이 data_mon\T314.csv에 저장되었습니다.
# T315 그룹이 data_mon\T315.csv에 저장되었습니다.
# T316 그룹이 data_mon\T316.csv에 저장되었습니다.
# T317 그룹이 data_mon\T317.csv에 저장되었습니다.
# T318 그룹이 data_mon\T318.csv에 저장되었습니다.
# T319 그룹이 data_mon\T319.csv에 저장되었습니다.
# T32 그룹이 data_mon\T32.csv에 저장되었습니다.
# T320 그룹이 data_mon\T320.csv에 저장되었습니다.
# T321 그룹이 data_mon\T321.csv에 저장되었습니다.
# T322 그룹이 data_mon\T322.csv에 저장되었습니다.
# T323 그룹이 data_mon\T323.csv에 저장되었습니다.
# T324 그룹이 data_mon\T324.csv에 저장되었습니다.
# T325 그룹이 data_mon\T325.csv에 저장되었습니다.
# T326 그룹이 data_mon\T326.csv에 저장되었습니다.
# T327 그룹이 data_mon\T327.csv에 저장되었습니다.
# T328 그룹이 data_mon\T328.csv에 저장되었습니다.
# T329 그룹이 data_mon\T329.csv에 저장되었습니다.
# T33 그룹이 data_mon\T33.csv에 저장되었습니다.
# T330 그룹이 data_mon\T330.csv에 저장되었습니다.
# T331 그룹이 data_mon\T331.csv에 저장되었습니다.
# T332 그룹이 data_mon\T332.csv에 저장되었습니다.
# T333 그룹이 data_mon\T333.csv에 저장되었습니다.
# T334 그룹이 data_mon\T334.csv에 저장되었습니다.
# T335 그룹이 data_mon\T335.csv에 저장되었습니다.
# T336 그룹이 data_mon\T336.csv에 저장되었습니다.
# T337 그룹이 data_mon\T337.csv에 저장되었습니다.
# T338 그룹이 data_mon\T338.csv에 저장되었습니다.
# T339 그룹이 data_mon\T339.csv에 저장되었습니다.
# T34 그룹이 data_mon\T34.csv에 저장되었습니다.
# T340 그룹이 data_mon\T340.csv에 저장되었습니다.
# T341 그룹이 data_mon\T341.csv에 저장되었습니다.
# T342 그룹이 data_mon\T342.csv에 저장되었습니다.
# T343 그룹이 data_mon\T343.csv에 저장되었습니다.
# T344 그룹이 data_mon\T344.csv에 저장되었습니다.
# T345 그룹이 data_mon\T345.csv에 저장되었습니다.
# T346 그룹이 data_mon\T346.csv에 저장되었습니다.
# T347 그룹이 data_mon\T347.csv에 저장되었습니다.
# T348 그룹이 data_mon\T348.csv에 저장되었습니다.
# T349 그룹이 data_mon\T349.csv에 저장되었습니다.
# T35 그룹이 data_mon\T35.csv에 저장되었습니다.
# T350 그룹이 data_mon\T350.csv에 저장되었습니다.
# T351 그룹이 data_mon\T351.csv에 저장되었습니다.
# T352 그룹이 data_mon\T352.csv에 저장되었습니다.
# T353 그룹이 data_mon\T353.csv에 저장되었습니다.
# T354 그룹이 data_mon\T354.csv에 저장되었습니다.
# T355 그룹이 data_mon\T355.csv에 저장되었습니다.
# T356 그룹이 data_mon\T356.csv에 저장되었습니다.
# T357 그룹이 data_mon\T357.csv에 저장되었습니다.
# T358 그룹이 data_mon\T358.csv에 저장되었습니다.
# T359 그룹이 data_mon\T359.csv에 저장되었습니다.
# T36 그룹이 data_mon\T36.csv에 저장되었습니다.
# T360 그룹이 data_mon\T360.csv에 저장되었습니다.
# T361 그룹이 data_mon\T361.csv에 저장되었습니다.
# T362 그룹이 data_mon\T362.csv에 저장되었습니다.
# T363 그룹이 data_mon\T363.csv에 저장되었습니다.
# T364 그룹이 data_mon\T364.csv에 저장되었습니다.
# T365 그룹이 data_mon\T365.csv에 저장되었습니다.
# T366 그룹이 data_mon\T366.csv에 저장되었습니다.
# T37 그룹이 data_mon\T37.csv에 저장되었습니다.
# T38 그룹이 data_mon\T38.csv에 저장되었습니다.
# T39 그룹이 data_mon\T39.csv에 저장되었습니다.
# T4 그룹이 data_mon\T4.csv에 저장되었습니다.
# T40 그룹이 data_mon\T40.csv에 저장되었습니다.
# T41 그룹이 data_mon\T41.csv에 저장되었습니다.
# T42 그룹이 data_mon\T42.csv에 저장되었습니다.
# T43 그룹이 data_mon\T43.csv에 저장되었습니다.
# T44 그룹이 data_mon\T44.csv에 저장되었습니다.
# T45 그룹이 data_mon\T45.csv에 저장되었습니다.
# T46 그룹이 data_mon\T46.csv에 저장되었습니다.
# T47 그룹이 data_mon\T47.csv에 저장되었습니다.
# T48 그룹이 data_mon\T48.csv에 저장되었습니다.
# T49 그룹이 data_mon\T49.csv에 저장되었습니다.
# T5 그룹이 data_mon\T5.csv에 저장되었습니다.
# T50 그룹이 data_mon\T50.csv에 저장되었습니다.
# T51 그룹이 data_mon\T51.csv에 저장되었습니다.
# T52 그룹이 data_mon\T52.csv에 저장되었습니다.
# T53 그룹이 data_mon\T53.csv에 저장되었습니다.
# T54 그룹이 data_mon\T54.csv에 저장되었습니다.
# T55 그룹이 data_mon\T55.csv에 저장되었습니다.
# T56 그룹이 data_mon\T56.csv에 저장되었습니다.
# T57 그룹이 data_mon\T57.csv에 저장되었습니다.
# T58 그룹이 data_mon\T58.csv에 저장되었습니다.
# T59 그룹이 data_mon\T59.csv에 저장되었습니다.
# T6 그룹이 data_mon\T6.csv에 저장되었습니다.
# T60 그룹이 data_mon\T60.csv에 저장되었습니다.
# T61 그룹이 data_mon\T61.csv에 저장되었습니다.
# T62 그룹이 data_mon\T62.csv에 저장되었습니다.
# T63 그룹이 data_mon\T63.csv에 저장되었습니다.
# T64 그룹이 data_mon\T64.csv에 저장되었습니다.
# T65 그룹이 data_mon\T65.csv에 저장되었습니다.
# T66 그룹이 data_mon\T66.csv에 저장되었습니다.
# T67 그룹이 data_mon\T67.csv에 저장되었습니다.
# T68 그룹이 data_mon\T68.csv에 저장되었습니다.
# T69 그룹이 data_mon\T69.csv에 저장되었습니다.
# T7 그룹이 data_mon\T7.csv에 저장되었습니다.
# T70 그룹이 data_mon\T70.csv에 저장되었습니다.
# T71 그룹이 data_mon\T71.csv에 저장되었습니다.
# T72 그룹이 data_mon\T72.csv에 저장되었습니다.
# T73 그룹이 data_mon\T73.csv에 저장되었습니다.
# T74 그룹이 data_mon\T74.csv에 저장되었습니다.
# T75 그룹이 data_mon\T75.csv에 저장되었습니다.
# T76 그룹이 data_mon\T76.csv에 저장되었습니다.
# T77 그룹이 data_mon\T77.csv에 저장되었습니다.
# T78 그룹이 data_mon\T78.csv에 저장되었습니다.
# T79 그룹이 data_mon\T79.csv에 저장되었습니다.
# T8 그룹이 data_mon\T8.csv에 저장되었습니다.
# T80 그룹이 data_mon\T80.csv에 저장되었습니다.
# T81 그룹이 data_mon\T81.csv에 저장되었습니다.
# T82 그룹이 data_mon\T82.csv에 저장되었습니다.
# T83 그룹이 data_mon\T83.csv에 저장되었습니다.
# T84 그룹이 data_mon\T84.csv에 저장되었습니다.
# T85 그룹이 data_mon\T85.csv에 저장되었습니다.
# T86 그룹이 data_mon\T86.csv에 저장되었습니다.
# T87 그룹이 data_mon\T87.csv에 저장되었습니다.
# T88 그룹이 data_mon\T88.csv에 저장되었습니다.
# T89 그룹이 data_mon\T89.csv에 저장되었습니다.
# T9 그룹이 data_mon\T9.csv에 저장되었습니다.
# T90 그룹이 data_mon\T90.csv에 저장되었습니다.
# T91 그룹이 data_mon\T91.csv에 저장되었습니다.
# T92 그룹이 data_mon\T92.csv에 저장되었습니다.
# T93 그룹이 data_mon\T93.csv에 저장되었습니다.
# T94 그룹이 data_mon\T94.csv에 저장되었습니다.
# T95 그룹이 data_mon\T95.csv에 저장되었습니다.
# T96 그룹이 data_mon\T96.csv에 저장되었습니다.
# T97 그룹이 data_mon\T97.csv에 저장되었습니다.
# T98 그룹이 data_mon\T98.csv에 저장되었습니다.
# T99 그룹이 data_mon\T99.csv에 저장되었습니다.

# %%
df = pd.read_csv("./data_mon/T1.csv")
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m')  # date 값을 연월 형식의 datetime으로 변환
df
# Out:
#     series_id       date      value
# 0          T1 1979-01-01  1149.8700
# 1          T1 1979-02-01  1053.8002
# 2          T1 1979-03-01  1388.8798
# 3          T1 1979-04-01  1783.3702
# 4          T1 1979-05-01  1921.0252
# ..        ...        ...        ...
# 182        T1 1994-03-01  2466.3100
# 183        T1 1994-04-01  2851.7150
# 184        T1 1994-05-01  3671.8050
# 185        T1 1994-06-01  3806.7800
# 186        T1 1994-07-01  6995.0500
#
# [187 rows x 3 columns]

# %%
df = df.sort_values('date')

# 데이터 시각화 (예시: 'price_mean' 컬럼)
plt.figure(figsize=(12,6))
plt.plot(df['date'], df['value'], marker='o', linestyle='-', label='value')
plt.xlabel('date')
plt.ylabel('Value')
plt.title('Tourism Monthly')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def run_stationarity_tests(series):
    print("=== ADF 검정 결과 ===")
    adf_result = adfuller(series, autolag='AIC')
    adf_stat, adf_p, adf_lags, adf_nobs, adf_crit, adf_icbest = adf_result
    print(f"검정 통계량: {adf_stat:.4f}")
    print(f"p-value: {adf_p:.4f}")
    print(f"사용된 lag 수: {adf_lags}")
    print(f"관측치 수: {adf_nobs}")
    print("임계값:")
    for key, value in adf_crit.items():
        print(f"  {key} 유의수준: {value:.4f}")
        
    # ADF 검정의 귀무가설은 "단위근이 존재하여 시계열이 비정상이다"입니다.
    # 검정 통계량이 임계값보다 작으면 귀무가설을 기각하여 정상성을 인정함.
    if adf_stat < adf_crit["5%"]:
        adf_conclusion = "정상"
        print("=> ADF 검정 결과: 귀무가설(비정상)을 기각합니다. 시계열은 정상입니다.\n")
    else:
        adf_conclusion = "비정상"
        print("=> ADF 검정 결과: 귀무가설(비정상)을 기각하지 못했습니다. 시계열은 비정상입니다.\n")
    
    print("=== KPSS 검정 결과 ===")
    kpss_result = kpss(series, regression='c', nlags="auto")
    kpss_stat, kpss_p, kpss_lags, kpss_crit = kpss_result
    print(f"검정 통계량: {kpss_stat:.4f}")
    print(f"p-value: {kpss_p:.4f}")
    print(f"사용된 lag 수: {kpss_lags}")
    print("임계값:")
    for key, value in kpss_crit.items():
        print(f"  {key} 유의수준: {value:.4f}")
        
    # KPSS 검정의 귀무가설은 "시계열이 정상이다"입니다.
    # 검정 통계량이 각 유의수준의 임계값보다 크면 귀무가설을 기각하여 비정상으로 판단합니다.
    kpss_conclusion = "정상"
    for level, crit in kpss_crit.items():
        if kpss_stat > crit:
            kpss_conclusion = "비정상"
            print(f"{level} 유의수준: KPSS 검정 통계량이 임계값보다 큽니다. (비정상)")
        else:
            print(f"{level} 유의수준: KPSS 검정 통계량이 임계값 이하입니다. (정상)")
    
    print("\n=== 종합 결과 ===")
    print(f"ADF 검정 결론: {adf_conclusion}")
    print(f"KPSS 검정 결론: {kpss_conclusion}")
    
    if adf_conclusion == "정상" and kpss_conclusion == "정상":
        print("=> 최종 결론: 시계열은 정상입니다.")
    elif adf_conclusion == "비정상" and kpss_conclusion == "비정상":
        print("=> 최종 결론: 시계열은 비정상입니다.")
    else:
        print("=> 최종 결론: 검정 결과가 상반됩니다. 추가 분석이 필요합니다.")

# 예시 사용:
series = df['value']
run_stationarity_tests(series)
# Out:
# === ADF 검정 결과 ===
# 검정 통계량: 0.1344
# p-value: 0.9683
# 사용된 lag 수: 13
# 관측치 수: 173
# 임계값:
#   1% 유의수준: -3.4687
#   5% 유의수준: -2.8784
#   10% 유의수준: -2.5758
# => ADF 검정 결과: 귀무가설(비정상)을 기각하지 못했습니다. 시계열은 비정상입니다.
#
# === KPSS 검정 결과 ===
# 검정 통계량: 0.8020
# p-value: 0.0100
# 사용된 lag 수: 5
# 임계값:
#   10% 유의수준: 0.3470
#   5% 유의수준: 0.4630
#   2.5% 유의수준: 0.5740
#   1% 유의수준: 0.7390
# 10% 유의수준: KPSS 검정 통계량이 임계값보다 큽니다. (비정상)
# 5% 유의수준: KPSS 검정 통계량이 임계값보다 큽니다. (비정상)
# 2.5% 유의수준: KPSS 검정 통계량이 임계값보다 큽니다. (비정상)
# 1% 유의수준: KPSS 검정 통계량이 임계값보다 큽니다. (비정상)
#
# === 종합 결과 ===
# ADF 검정 결론: 비정상
# KPSS 검정 결론: 비정상
# => 최종 결론: 시계열은 비정상입니다.
# C:\Users\admin\AppData\Local\Temp\ipykernel_29228\3863543515.py:23: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_result = kpss(series, regression='c', nlags="auto")

# %%
plot_acf(df['value'], lags=50)
plt.show()

plot_pacf(df['value'], lags=50)
plt.show()

# %%
import os
import pandas as pd
import glob

# CSV 파일들이 있는 디렉토리 경로
directory = "./data_mon"

# 디렉토리 내의 모든 CSV 파일 찾기
csv_files = glob.glob(os.path.join(directory, "*.csv"))

for csv_file in csv_files:
    # CSV 파일 읽기
    df = pd.read_csv(csv_file)
    
    # 'series_id' 칼럼이 있는 경우 제거
    if 'series_id' in df.columns:
        df = df.drop(columns=['series_id'])
        # 변경된 데이터프레임을 원본 파일에 덮어쓰기 (인덱스는 저장하지 않음)
        df.to_csv(csv_file, index=False)
        print(f"Processed file: {csv_file}")
    else:
        print(f"'series_id' column not found in: {csv_file}")
# Out:
# Processed file: ./data_mon\T1.csv
# Processed file: ./data_mon\T10.csv
# Processed file: ./data_mon\T100.csv
# Processed file: ./data_mon\T101.csv
# Processed file: ./data_mon\T102.csv
# Processed file: ./data_mon\T103.csv
# Processed file: ./data_mon\T104.csv
# Processed file: ./data_mon\T105.csv
# Processed file: ./data_mon\T106.csv
# Processed file: ./data_mon\T107.csv
# Processed file: ./data_mon\T108.csv
# Processed file: ./data_mon\T109.csv
# Processed file: ./data_mon\T11.csv
# Processed file: ./data_mon\T110.csv
# Processed file: ./data_mon\T111.csv
# Processed file: ./data_mon\T112.csv
# Processed file: ./data_mon\T113.csv
# Processed file: ./data_mon\T114.csv
# Processed file: ./data_mon\T115.csv
# Processed file: ./data_mon\T116.csv
# Processed file: ./data_mon\T117.csv
# Processed file: ./data_mon\T118.csv
# Processed file: ./data_mon\T119.csv
# Processed file: ./data_mon\T12.csv
# Processed file: ./data_mon\T120.csv
# Processed file: ./data_mon\T121.csv
# Processed file: ./data_mon\T122.csv
# Processed file: ./data_mon\T123.csv
# Processed file: ./data_mon\T124.csv
# Processed file: ./data_mon\T125.csv
# Processed file: ./data_mon\T126.csv
# Processed file: ./data_mon\T127.csv
# Processed file: ./data_mon\T128.csv
# Processed file: ./data_mon\T129.csv
# Processed file: ./data_mon\T13.csv
# Processed file: ./data_mon\T130.csv
# Processed file: ./data_mon\T131.csv
# Processed file: ./data_mon\T132.csv
# Processed file: ./data_mon\T133.csv
# Processed file: ./data_mon\T134.csv
# Processed file: ./data_mon\T135.csv
# Processed file: ./data_mon\T136.csv
# Processed file: ./data_mon\T137.csv
# Processed file: ./data_mon\T138.csv
# Processed file: ./data_mon\T139.csv
# Processed file: ./data_mon\T14.csv
# Processed file: ./data_mon\T140.csv
# Processed file: ./data_mon\T141.csv
# Processed file: ./data_mon\T142.csv
# Processed file: ./data_mon\T143.csv
# Processed file: ./data_mon\T144.csv
# Processed file: ./data_mon\T145.csv
# Processed file: ./data_mon\T146.csv
# Processed file: ./data_mon\T147.csv
# Processed file: ./data_mon\T148.csv
# Processed file: ./data_mon\T149.csv
# Processed file: ./data_mon\T15.csv
# Processed file: ./data_mon\T150.csv
# Processed file: ./data_mon\T151.csv
# Processed file: ./data_mon\T152.csv
# Processed file: ./data_mon\T153.csv
# Processed file: ./data_mon\T154.csv
# Processed file: ./data_mon\T155.csv
# Processed file: ./data_mon\T156.csv
# Processed file: ./data_mon\T157.csv
# Processed file: ./data_mon\T158.csv
# Processed file: ./data_mon\T159.csv
# Processed file: ./data_mon\T16.csv
# Processed file: ./data_mon\T160.csv
# Processed file: ./data_mon\T161.csv
# Processed file: ./data_mon\T162.csv
# Processed file: ./data_mon\T163.csv
# Processed file: ./data_mon\T164.csv
# Processed file: ./data_mon\T165.csv
# Processed file: ./data_mon\T166.csv
# Processed file: ./data_mon\T167.csv
# Processed file: ./data_mon\T168.csv
# Processed file: ./data_mon\T169.csv
# Processed file: ./data_mon\T17.csv
# Processed file: ./data_mon\T170.csv
# Processed file: ./data_mon\T171.csv
# Processed file: ./data_mon\T172.csv
# Processed file: ./data_mon\T173.csv
# Processed file: ./data_mon\T174.csv
# Processed file: ./data_mon\T175.csv
# Processed file: ./data_mon\T176.csv
# Processed file: ./data_mon\T177.csv
# Processed file: ./data_mon\T178.csv
# Processed file: ./data_mon\T179.csv
# Processed file: ./data_mon\T18.csv
# Processed file: ./data_mon\T180.csv
# Processed file: ./data_mon\T181.csv
# Processed file: ./data_mon\T182.csv
# Processed file: ./data_mon\T183.csv
# Processed file: ./data_mon\T184.csv
# Processed file: ./data_mon\T185.csv
# Processed file: ./data_mon\T186.csv
# Processed file: ./data_mon\T187.csv
# Processed file: ./data_mon\T188.csv
# Processed file: ./data_mon\T189.csv
# Processed file: ./data_mon\T19.csv
# Processed file: ./data_mon\T190.csv
# Processed file: ./data_mon\T191.csv
# Processed file: ./data_mon\T192.csv
# Processed file: ./data_mon\T193.csv
# Processed file: ./data_mon\T194.csv
# Processed file: ./data_mon\T195.csv
# Processed file: ./data_mon\T196.csv
# Processed file: ./data_mon\T197.csv
# Processed file: ./data_mon\T198.csv
# Processed file: ./data_mon\T199.csv
# Processed file: ./data_mon\T2.csv
# Processed file: ./data_mon\T20.csv
# Processed file: ./data_mon\T200.csv
# Processed file: ./data_mon\T201.csv
# Processed file: ./data_mon\T202.csv
# Processed file: ./data_mon\T203.csv
# Processed file: ./data_mon\T204.csv
# Processed file: ./data_mon\T205.csv
# Processed file: ./data_mon\T206.csv
# Processed file: ./data_mon\T207.csv
# Processed file: ./data_mon\T208.csv
# Processed file: ./data_mon\T209.csv
# Processed file: ./data_mon\T21.csv
# Processed file: ./data_mon\T210.csv
# Processed file: ./data_mon\T211.csv
# Processed file: ./data_mon\T212.csv
# Processed file: ./data_mon\T213.csv
# Processed file: ./data_mon\T214.csv
# Processed file: ./data_mon\T215.csv
# Processed file: ./data_mon\T216.csv
# Processed file: ./data_mon\T217.csv
# Processed file: ./data_mon\T218.csv
# Processed file: ./data_mon\T219.csv
# Processed file: ./data_mon\T22.csv
# Processed file: ./data_mon\T220.csv
# Processed file: ./data_mon\T221.csv
# Processed file: ./data_mon\T222.csv
# Processed file: ./data_mon\T223.csv
# Processed file: ./data_mon\T224.csv
# Processed file: ./data_mon\T225.csv
# Processed file: ./data_mon\T226.csv
# Processed file: ./data_mon\T227.csv
# Processed file: ./data_mon\T228.csv
# Processed file: ./data_mon\T229.csv
# Processed file: ./data_mon\T23.csv
# Processed file: ./data_mon\T230.csv
# Processed file: ./data_mon\T231.csv
# Processed file: ./data_mon\T232.csv
# Processed file: ./data_mon\T233.csv
# Processed file: ./data_mon\T234.csv
# Processed file: ./data_mon\T235.csv
# Processed file: ./data_mon\T236.csv
# Processed file: ./data_mon\T237.csv
# Processed file: ./data_mon\T238.csv
# Processed file: ./data_mon\T239.csv
# Processed file: ./data_mon\T24.csv
# Processed file: ./data_mon\T240.csv
# Processed file: ./data_mon\T241.csv
# Processed file: ./data_mon\T242.csv
# Processed file: ./data_mon\T243.csv
# Processed file: ./data_mon\T244.csv
# Processed file: ./data_mon\T245.csv
# Processed file: ./data_mon\T246.csv
# Processed file: ./data_mon\T247.csv
# Processed file: ./data_mon\T248.csv
# Processed file: ./data_mon\T249.csv
# Processed file: ./data_mon\T25.csv
# Processed file: ./data_mon\T250.csv
# Processed file: ./data_mon\T251.csv
# Processed file: ./data_mon\T252.csv
# Processed file: ./data_mon\T253.csv
# Processed file: ./data_mon\T254.csv
# Processed file: ./data_mon\T255.csv
# Processed file: ./data_mon\T256.csv
# Processed file: ./data_mon\T257.csv
# Processed file: ./data_mon\T258.csv
# Processed file: ./data_mon\T259.csv
# Processed file: ./data_mon\T26.csv
# Processed file: ./data_mon\T260.csv
# Processed file: ./data_mon\T261.csv
# Processed file: ./data_mon\T262.csv
# Processed file: ./data_mon\T263.csv
# Processed file: ./data_mon\T264.csv
# Processed file: ./data_mon\T265.csv
# Processed file: ./data_mon\T266.csv
# Processed file: ./data_mon\T267.csv
# Processed file: ./data_mon\T268.csv
# Processed file: ./data_mon\T269.csv
# Processed file: ./data_mon\T27.csv
# Processed file: ./data_mon\T270.csv
# Processed file: ./data_mon\T271.csv
# Processed file: ./data_mon\T272.csv
# Processed file: ./data_mon\T273.csv
# Processed file: ./data_mon\T274.csv
# Processed file: ./data_mon\T275.csv
# Processed file: ./data_mon\T276.csv
# Processed file: ./data_mon\T277.csv
# Processed file: ./data_mon\T278.csv
# Processed file: ./data_mon\T279.csv
# Processed file: ./data_mon\T28.csv
# Processed file: ./data_mon\T280.csv
# Processed file: ./data_mon\T281.csv
# Processed file: ./data_mon\T282.csv
# Processed file: ./data_mon\T283.csv
# Processed file: ./data_mon\T284.csv
# Processed file: ./data_mon\T285.csv
# Processed file: ./data_mon\T286.csv
# Processed file: ./data_mon\T287.csv
# Processed file: ./data_mon\T288.csv
# Processed file: ./data_mon\T289.csv
# Processed file: ./data_mon\T29.csv
# Processed file: ./data_mon\T290.csv
# Processed file: ./data_mon\T291.csv
# Processed file: ./data_mon\T292.csv
# Processed file: ./data_mon\T293.csv
# Processed file: ./data_mon\T294.csv
# Processed file: ./data_mon\T295.csv
# Processed file: ./data_mon\T296.csv
# Processed file: ./data_mon\T297.csv
# Processed file: ./data_mon\T298.csv
# Processed file: ./data_mon\T299.csv
# Processed file: ./data_mon\T3.csv
# Processed file: ./data_mon\T30.csv
# Processed file: ./data_mon\T300.csv
# Processed file: ./data_mon\T301.csv
# Processed file: ./data_mon\T302.csv
# Processed file: ./data_mon\T303.csv
# Processed file: ./data_mon\T304.csv
# Processed file: ./data_mon\T305.csv
# Processed file: ./data_mon\T306.csv
# Processed file: ./data_mon\T307.csv
# Processed file: ./data_mon\T308.csv
# Processed file: ./data_mon\T309.csv
# Processed file: ./data_mon\T31.csv
# Processed file: ./data_mon\T310.csv
# Processed file: ./data_mon\T311.csv
# Processed file: ./data_mon\T312.csv
# Processed file: ./data_mon\T313.csv
# Processed file: ./data_mon\T314.csv
# Processed file: ./data_mon\T315.csv
# Processed file: ./data_mon\T316.csv
# Processed file: ./data_mon\T317.csv
# Processed file: ./data_mon\T318.csv
# Processed file: ./data_mon\T319.csv
# Processed file: ./data_mon\T32.csv
# Processed file: ./data_mon\T320.csv
# Processed file: ./data_mon\T321.csv
# Processed file: ./data_mon\T322.csv
# Processed file: ./data_mon\T323.csv
# Processed file: ./data_mon\T324.csv
# Processed file: ./data_mon\T325.csv
# Processed file: ./data_mon\T326.csv
# Processed file: ./data_mon\T327.csv
# Processed file: ./data_mon\T328.csv
# Processed file: ./data_mon\T329.csv
# Processed file: ./data_mon\T33.csv
# Processed file: ./data_mon\T330.csv
# Processed file: ./data_mon\T331.csv
# Processed file: ./data_mon\T332.csv
# Processed file: ./data_mon\T333.csv
# Processed file: ./data_mon\T334.csv
# Processed file: ./data_mon\T335.csv
# Processed file: ./data_mon\T336.csv
# Processed file: ./data_mon\T337.csv
# Processed file: ./data_mon\T338.csv
# Processed file: ./data_mon\T339.csv
# Processed file: ./data_mon\T34.csv
# Processed file: ./data_mon\T340.csv
# Processed file: ./data_mon\T341.csv
# Processed file: ./data_mon\T342.csv
# Processed file: ./data_mon\T343.csv
# Processed file: ./data_mon\T344.csv
# Processed file: ./data_mon\T345.csv
# Processed file: ./data_mon\T346.csv
# Processed file: ./data_mon\T347.csv
# Processed file: ./data_mon\T348.csv
# Processed file: ./data_mon\T349.csv
# Processed file: ./data_mon\T35.csv
# Processed file: ./data_mon\T350.csv
# Processed file: ./data_mon\T351.csv
# Processed file: ./data_mon\T352.csv
# Processed file: ./data_mon\T353.csv
# Processed file: ./data_mon\T354.csv
# Processed file: ./data_mon\T355.csv
# Processed file: ./data_mon\T356.csv
# Processed file: ./data_mon\T357.csv
# Processed file: ./data_mon\T358.csv
# Processed file: ./data_mon\T359.csv
# Processed file: ./data_mon\T36.csv
# Processed file: ./data_mon\T360.csv
# Processed file: ./data_mon\T361.csv
# Processed file: ./data_mon\T362.csv
# Processed file: ./data_mon\T363.csv
# Processed file: ./data_mon\T364.csv
# Processed file: ./data_mon\T365.csv
# Processed file: ./data_mon\T366.csv
# Processed file: ./data_mon\T37.csv
# Processed file: ./data_mon\T38.csv
# Processed file: ./data_mon\T39.csv
# Processed file: ./data_mon\T4.csv
# Processed file: ./data_mon\T40.csv
# Processed file: ./data_mon\T41.csv
# Processed file: ./data_mon\T42.csv
# Processed file: ./data_mon\T43.csv
# Processed file: ./data_mon\T44.csv
# Processed file: ./data_mon\T45.csv
# Processed file: ./data_mon\T46.csv
# Processed file: ./data_mon\T47.csv
# Processed file: ./data_mon\T48.csv
# Processed file: ./data_mon\T49.csv
# Processed file: ./data_mon\T5.csv
# Processed file: ./data_mon\T50.csv
# Processed file: ./data_mon\T51.csv
# Processed file: ./data_mon\T52.csv
# Processed file: ./data_mon\T53.csv
# Processed file: ./data_mon\T54.csv
# Processed file: ./data_mon\T55.csv
# Processed file: ./data_mon\T56.csv
# Processed file: ./data_mon\T57.csv
# Processed file: ./data_mon\T58.csv
# Processed file: ./data_mon\T59.csv
# Processed file: ./data_mon\T6.csv
# Processed file: ./data_mon\T60.csv
# Processed file: ./data_mon\T61.csv
# Processed file: ./data_mon\T62.csv
# Processed file: ./data_mon\T63.csv
# Processed file: ./data_mon\T64.csv
# Processed file: ./data_mon\T65.csv
# Processed file: ./data_mon\T66.csv
# Processed file: ./data_mon\T67.csv
# Processed file: ./data_mon\T68.csv
# Processed file: ./data_mon\T69.csv
# Processed file: ./data_mon\T7.csv
# Processed file: ./data_mon\T70.csv
# Processed file: ./data_mon\T71.csv
# Processed file: ./data_mon\T72.csv
# Processed file: ./data_mon\T73.csv
# Processed file: ./data_mon\T74.csv
# Processed file: ./data_mon\T75.csv
# Processed file: ./data_mon\T76.csv
# Processed file: ./data_mon\T77.csv
# Processed file: ./data_mon\T78.csv
# Processed file: ./data_mon\T79.csv
# Processed file: ./data_mon\T8.csv
# Processed file: ./data_mon\T80.csv
# Processed file: ./data_mon\T81.csv
# Processed file: ./data_mon\T82.csv
# Processed file: ./data_mon\T83.csv
# Processed file: ./data_mon\T84.csv
# Processed file: ./data_mon\T85.csv
# Processed file: ./data_mon\T86.csv
# Processed file: ./data_mon\T87.csv
# Processed file: ./data_mon\T88.csv
# Processed file: ./data_mon\T89.csv
# Processed file: ./data_mon\T9.csv
# Processed file: ./data_mon\T90.csv
# Processed file: ./data_mon\T91.csv
# Processed file: ./data_mon\T92.csv
# Processed file: ./data_mon\T93.csv
# Processed file: ./data_mon\T94.csv
# Processed file: ./data_mon\T95.csv
# Processed file: ./data_mon\T96.csv
# Processed file: ./data_mon\T97.csv
# Processed file: ./data_mon\T98.csv
# Processed file: ./data_mon\T99.csv

# %%
import os
import pandas as pd
import numpy as np
import time
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# ----------------------------
# Model Libraries
# ----------------------------
# ARIMA: SARIMAX from statsmodels
from statsmodels.tsa.statespace.sarimax import SARIMAX
# SES and ETS: SimpleExpSmoothing and ExponentialSmoothing from statsmodels
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, ExponentialSmoothing
# Prophet
from prophet import Prophet
# TBATS from tbats package
try:
    from tbats import TBATS
except Exception as e:
    print("TBATS 라이브러리가 설치되어 있지 않습니다.", e)
# Theta: from statsforecast
try:
    from statsforecast.models import Theta
    from statsforecast import StatsForecast
except Exception as e:
    print("Theta 모델 관련 라이브러리가 설치되어 있지 않습니다.", e)

# ----------------------------
# Evaluation Metric Functions
# ----------------------------
def calc_smape(actual, forecast, eps=1e-8):
    """Symmetric Mean Absolute Percentage Error"""
    return 100 * np.mean(2 * np.abs(forecast - actual) / (np.abs(actual) + np.abs(forecast) + eps))

def calc_mase(actual, forecast, train, eps=1e-8):
    """Mean Absolute Scaled Error using naive forecast (lag=1) for scaling"""
    mae = mean_absolute_error(actual, forecast)
    naive = train.shift(1)
    scale = np.mean(np.abs(train.dropna() - naive.dropna()))
    return mae / (scale + eps)

# ----------------------------
# 설정: CSV 파일들이 들어 있는 폴더 경로 (월간 데이터)
# ----------------------------
input_folder = "./data_mon"  # 실제 경로로 수정

# 결과를 저장할 리스트 (각 파일의 모델별 평가 결과 누적)
all_results = []

# ----------------------------
# 폴더 내의 각 CSV 파일 처리
# ----------------------------
for file in os.listdir(input_folder):
    if not file.endswith(".csv"):
        continue
    file_path = os.path.join(input_folder, file)
    
    try:
        # CSV 파일 읽기 (첫 번째 컬럼이 날짜 인덱스라고 가정)
        df_file = pd.read_csv(file_path, parse_dates=True, index_col=0)
    except Exception as e:
        print(f"{file} 읽기 에러: {e}")
        continue

    if 'value' not in df_file.columns:
        print(f"{file} 스킵: 'value' 컬럼 없음")
        continue

    # 인덱스를 datetime으로 강제 변환
    df_file.index = pd.to_datetime(df_file.index)
    
    # 타겟 시계열: value
    series = df_file['value'].dropna()
    if series.empty:
        print(f"{file} 스킵: 시계열 데이터가 비어 있음")
        continue

    # ----------------------------
    # 데이터 분할: 80% 학습, 20% 테스트
    # ----------------------------
    n_total = len(series)
    split_index = int(n_total * 0.8)
    train_series = series.iloc[:split_index]
    test_series = series.iloc[split_index:]
    horizon = len(test_series)
    actual = test_series.copy()
    
    # MASE 계산을 위한 scale: training 데이터의 naive forecast (lag=1)
    naive_forecast = train_series.shift(1)
    scale = np.mean(np.abs(train_series.dropna() - naive_forecast.dropna()))
    
    file_results = []  # 파일별 모델 평가 결과 저장 리스트

    # ----------------------------
    # Model 1: ARIMA (ARMA) using SARIMAX
    # 비정상 시계열 예측용으로 d=1, seasonal_order=(0,1,1,12) 사용 (주기가 12)
    # ----------------------------
    try:
        start = time.time()
        model_arima = SARIMAX(train_series, order=(1,1,1), seasonal_order=(0,1,1,12))
        fit_arima = model_arima.fit(disp=False)
        forecast_arima = fit_arima.forecast(steps=horizon)
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_arima)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_arima))
        smape_val = calc_smape(actual.values, forecast_arima.values)
        mase_val = calc_mase(actual, forecast_arima, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'ARIMA',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - ARIMA 완료")
    except Exception as e:
        print(f"{file} - ARIMA 모델 에러: {e}")
    
    # ----------------------------
    # Model 2: SES using SimpleExpSmoothing
    # ----------------------------
    try:
        start = time.time()
        model_ses = SimpleExpSmoothing(train_series).fit(optimized=True)
        forecast_ses = model_ses.forecast(steps=horizon)
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_ses)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_ses))
        smape_val = calc_smape(actual.values, forecast_ses.values)
        mase_val = calc_mase(actual, forecast_ses, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'SES',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - SES 완료")
    except Exception as e:
        print(f"{file} - SES 모델 에러: {e}")
    
    # ----------------------------
    # Model 3: Theta using statsforecast
    # ----------------------------
    try:
        start = time.time()
        train_df = pd.DataFrame({
            'ds': train_series.index, 
            'y': train_series.values, 
            'unique_id': 'series'
        })
        sf = StatsForecast(train_df, models=[Theta()], freq='M')
        forecast_df = sf.forecast(horizon, train_df)
        forecast_theta = forecast_df['Theta']
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_theta)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_theta))
        smape_val = calc_smape(actual.values, forecast_theta.values)
        mase_val = calc_mase(actual, forecast_theta, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'Theta',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - Theta 완료")
    except Exception as e:
        print(f"{file} - Theta 모델 에러: {e}")
    
    # ----------------------------
    # Model 4: TBATS using tbats package
    # ----------------------------
    # try:
    #     start = time.time()
    #     # 데이터에 특별한 계절성이 없다고 가정하여 seasonal_periods 빈 리스트 사용
    #     estimator = TBATS(seasonal_periods=[])
    #     model_tbats = estimator.fit(train_series.values)
    #     forecast_tbats = model_tbats.forecast(steps=horizon)
    #     forecast_tbats = pd.Series(forecast_tbats, index=test_series.index)
    #     end = time.time()
    #     exec_time = end - start
    # 
    #     mae_val = mean_absolute_error(actual, forecast_tbats)
    #     rmse_val = np.sqrt(mean_squared_error(actual, forecast_tbats))
    #     smape_val = calc_smape(actual.values, forecast_tbats.values)
    #     mase_val = calc_mase(actual, forecast_tbats, train_series)
    #     
    #     file_results.append({
    #         'File': file,
    #         'Model': 'TBATS',
    #         'sMAPE': smape_val,
    #         'MASE': mase_val,
    #         'MAE': mae_val,
    #         'RMSE': rmse_val,
    #         'Execution Time': exec_time
    #     })
    #     print(f"{file} - TBATS 완료")
    # except Exception as e:
    #     print(f"{file} - TBATS 모델 에러: {e}")
    
    # ----------------------------
    # Model 5: ETS using ExponentialSmoothing
    # ----------------------------
    try:
        start = time.time()
        # 비정상 시계열 예측을 위해 additive 추세와 계절성을 사용 (seasonal_periods=12)
        model_ets = ExponentialSmoothing(train_series, trend='add', seasonal='add', seasonal_periods=12).fit(optimized=True)
        forecast_ets = model_ets.forecast(steps=horizon)
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_ets)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_ets))
        smape_val = calc_smape(actual.values, forecast_ets.values)
        mase_val = calc_mase(actual, forecast_ets, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'ETS',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - ETS 완료")
    except Exception as e:
        print(f"{file} - ETS 모델 에러: {e}")
    
    # ----------------------------
    # Model 6: Prophet
    # ----------------------------
    try:
        start = time.time()
        train_prophet = pd.DataFrame({
            'ds': train_series.index, 
            'y': train_series.values
        })
        # Prophet은 ds에 타임존 정보가 있으면 에러 발생하므로 제거
        train_prophet['ds'] = pd.to_datetime(train_prophet['ds']).dt.tz_localize(None)
        model_prophet = Prophet()
        model_prophet.fit(train_prophet)
        future = model_prophet.make_future_dataframe(periods=horizon, freq='M', include_history=False)
        future['ds'] = pd.to_datetime(future['ds']).dt.tz_localize(None)
        forecast_prophet = model_prophet.predict(future)
        forecast_prophet = pd.Series(forecast_prophet['yhat'].values, index=test_series.index)
        end = time.time()
        exec_time = end - start

        mae_val = mean_absolute_error(actual, forecast_prophet)
        rmse_val = np.sqrt(mean_squared_error(actual, forecast_prophet))
        smape_val = calc_smape(actual.values, forecast_prophet.values)
        mase_val = calc_mase(actual, forecast_prophet, train_series)
        
        file_results.append({
            'File': file,
            'Model': 'Prophet',
            'sMAPE': smape_val,
            'MASE': mase_val,
            'MAE': mae_val,
            'RMSE': rmse_val,
            'Execution Time': exec_time
        })
        print(f"{file} - Prophet 완료")
    except Exception as e:
        print(f"{file} - Prophet 모델 에러: {e}")
    
    # 파일별 결과를 전체 결과 리스트에 추가
    for res in file_results:
        res['File'] = file  # 파일 이름 추가
    all_results.extend(file_results)

# ----------------------------
# 전체 데이터셋에 대한 모델별 평균 평가 지표 계산
# ----------------------------
results_df = pd.DataFrame(all_results)
if not results_df.empty:
    avg_results = results_df.drop(columns=['File']).groupby('Model').mean().reset_index()
    avg_results.to_csv("data_mon_forecast_evaluation_avg_metrics.csv", index=False)
    print("전체 데이터셋에 대한 평균 평가 지표가 'data_mon_forecast_evaluation_avg_metrics.csv'에 저장되었습니다.")
    print(avg_results)
else:
    print("평가 결과가 없습니다.")
